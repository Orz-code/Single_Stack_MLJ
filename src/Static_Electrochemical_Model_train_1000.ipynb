# %% [markdown]
# # 电化学部分的建模使用拟合经验模型的方法

# %% [markdown]
# ## import需要的库

# %%
import os,gzip,pickle
from utils.keys import DataDir,Cols
import numpy as np
import pandas as pd
import torch
from torch.utils.data import random_split
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置字体
matplotlib.rcParams['font.family'] = 'Microsoft YaHei, Times New Roman'
# 全局设置字号
plt.rcParams.update({
    'font.size': 16,  # 基础字号
    'axes.titlesize': 20,  # 标题字号
    'axes.labelsize': 20,  # 坐标轴标签字号
    'xtick.labelsize': 20,  # x轴刻度标签字号
    'ytick.labelsize': 20,  # y轴刻度标签字号
    'legend.fontsize': 16  # 图例字号
})
# 解决负号显示问题
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 导入数据与数据预处理

# %%
with gzip.open(
    r'D:\Devs\Single_Stack_MLJ\data\processed\XINYUAN\包头1000方数据1#2025-12.01-12.30 gzip',
    'rb'
) as f:
    df_XY = pickle.load(f)

df_XY[Cols.lye_flow] = df_XY[Cols.lye_flow].rolling(window=10, min_periods=1, center=True).mean()  # min_periods=1 确保首个数据直接保留

# %% [markdown]
# ### 筛选数据点

# %%
import matplotlib.dates as mdates

# 确保时间列是 datetime，避免 x 轴显示成字符串或序号
df_plot = df_XY.copy()
df_plot[Cols.date_time] = pd.to_datetime(df_plot[Cols.date_time], errors='coerce')
df_plot = df_plot.dropna(subset=[Cols.date_time]).sort_values(Cols.date_time)

# 创建图表和子图
fig, ax1 = plt.subplots(figsize=(18, 10))

# 仅绘制 y 方向网格，降低视觉干扰
ax1.grid(True, axis='y', alpha=0.25)

# 绘制电流密度曲线
ax1.plot(df_plot[Cols.date_time], df_plot[Cols.current_density], c='#1f77b4', alpha=0.8, label='Current density (A/m$^2$)')
ax1.set_ylabel('Current density (A/m$^2$)', color='#1f77b4')
ax1.set_xlabel('Date time')
ax1.tick_params('y', colors='#1f77b4')

# x 轴日期刻度：固定每 6 小时一个刻度，保证时间间隔均匀
locator = mdates.HourLocator(interval=120)  # 每 120 小时（5 天）一个刻度
formatter = mdates.DateFormatter('%m-%d %H:%M')
ax1.xaxis.set_major_locator(locator)
ax1.xaxis.set_major_formatter(formatter)
plt.setp(ax1.get_xticklabels(), rotation=0, ha='center')

# 创建第二个 y 轴
ax2 = ax1.twinx()
ax2.plot(df_plot[Cols.date_time], df_plot[Cols.lye_flow], alpha=0.8, c='#7f7f7f', label='Lye flow rate (m$^3$/h)')
ax2.set_ylabel('Lye flow rate (m$^3$/h)', color='#7f7f7f')
ax2.tick_params('y', colors='#7f7f7f')

# 创建第三个 y 轴
ax3 = ax1.twinx()
ax3.plot(df_plot[Cols.date_time], df_plot[Cols.cell_voltage], c='#2ca02c', alpha=0.8, label='Cell voltage (V)')
ax3.set_ylabel('Cell voltage (V)', color='#2ca02c')
ax3.spines['right'].set_position(('outward', 90))
ax3.tick_params('y', colors='#2ca02c')

# 创建第四个 y 轴
ax4 = ax1.twinx()
ax4.plot(df_plot[Cols.date_time], df_plot[Cols.temp_out], c='#d62728', label='Temp out (℃)')
ax4.set_ylabel('Temp out (℃)', color='#d62728')
ax4.spines['right'].set_position(('outward', 180))
ax4.tick_params('y', colors='#d62728')

# 添加图例
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
lines4, labels4 = ax4.get_legend_handles_labels()
ax1.legend(lines + lines2 + lines3 + lines4, labels + labels2 + labels3 + labels4,
           loc='upper center', fontsize=19, bbox_to_anchor=(0.5, -0.1),
           ncol=4, frameon=True, fancybox=True, shadow=True)

plt.tight_layout()
plt.show()

# %%
# 计算简单移动平均（窗口大小=10）
df_voltage_XY = df_XY.copy()
df_voltage_XY[Cols.cell_voltage] = df_voltage_XY[Cols.cell_voltage].rolling(window=10, min_periods=1, center=True).mean()  # min_periods=1 确保首个数据直接保留

# %%
# 计算当前行温度与后一行温度的变化率
df_static_XY = df_voltage_XY

# 计算前后 5 个点（（窗口大小为 11，即10min））的极差
window_size = 11
df_static_XY['temp_diff'] = df_static_XY[Cols.temp_out].rolling(window=window_size, center=True, min_periods=1).apply(lambda x: x.max() - x.min())

# 筛选出温度变化值小于 0.2 的行
df_static_XY = df_static_XY[df_static_XY['temp_diff'] < 0.2]

# 过滤无效工况，避免后续 log/除法出现 NaN 或 Inf
valid_mask = (
    (df_static_XY[Cols.lye_temp] > 0) &
    (df_static_XY[Cols.temp_out] > 0) &
    (df_static_XY[Cols.current_density] > 0) &
    (df_static_XY[Cols.lye_flow] > 0) &
    (df_static_XY[Cols.pressure] > 0) &
    (df_static_XY[Cols.cell_voltage] > 0)
)
df_static_XY = df_static_XY[valid_mask].copy()

print(f"过滤后样本数: {len(df_static_XY)}")
# Out:
# 过滤后样本数: 27143

# %% [markdown]
# #### 冷却流量比

# %%
Num_Cells = 280
Diameter_Electrode = 1832E-3
Width_Cell = 12E-3

Volume_active = math.pi * (Diameter_Electrode / 2) ** 2 * Width_Cell * Num_Cells
lambda_flow_range = df_static_XY[Cols.lye_flow] / Volume_active / 0.51 - 12.37

print(lambda_flow_range.min(), lambda_flow_range.max())
# Out:
# 0.2556311655629173 0.7083650904020562

# %% [markdown]
# ## 在基础公式的基础上拟合经验参数(部分拟合)

# %% [markdown]
# ### 定义经验公式

# %%
Faraday = 96485
R = 8.314

# 定义经验公式
def Vrev_cal(lye_temp, temp_out, pressure):
    temp_work = (lye_temp + temp_out) / 2 + 273

    temp_ref = 298  # 参考点温度: K
    pressure_ref = 1  # 参考点压力: bar
    pressure = pressure * 10  # 公式中压力单位bar，单位转换
    z = 2  # 单位摩尔反应转移的电子数: mol

    delta_H0_H2O = -2.86E5  # 参考点状态下的焓变(单位：J / mol)
    delta_H0_H2 = 0  # 参考点状态下的焓变(单位：J / mol)
    delta_H0_O2 = 0  # 参考点状态下的焓变(单位：J / mol)

    s0_H2O = 70  # 参考点状态下的熵值(单位：J / (K * mol))
    s0_H2 = 131  # 参考点状态下的熵值(单位：J / (K * mol))
    s0_O2 = 205  # 参考点状态下的熵值(单位：J / (K * mol))

    Cp0_H2O = 75  # 参考点状态下的水热容(单位：J / (K * mol))
    Cp0_H2 = 29  # 参考点状态下的氢气热容(单位：J / (K * mol))
    Cp0_O2 = 29  # 参考点状态下的氧气热容(单位：J / (K * mol))

    delta_H_H2 = Cp0_H2 * (temp_work - temp_ref) + delta_H0_H2
    delta_H_O2 = Cp0_O2 * (temp_work - temp_ref) + delta_H0_O2
    delta_H_H2O = Cp0_H2O * (temp_work - temp_ref) + delta_H0_H2O
    delta_H = delta_H_H2 + 0.5 * delta_H_O2 - delta_H_H2O

    S_H2 = Cp0_H2 * torch.log(temp_work / temp_ref) - R * torch.log(pressure / pressure_ref) + s0_H2
    S_O2 = Cp0_O2 * torch.log(temp_work / temp_ref) - R * torch.log(pressure / pressure_ref) + s0_O2
    S_H2O = Cp0_H2O * torch.log(temp_work / temp_ref) + s0_H2O

    Delta_S = S_H2 + 0.5 * S_O2 - S_H2O

    delta_G = delta_H - temp_work * Delta_S
    
    Vrev = delta_G / (z * Faraday)  # 可逆电压

    return Vrev


def cell_voltage_cal_empirical_formula(statistics, r1, r2, s1, t1, t2, t3, c1, c2):
    lye_temp = statistics[0]
    temp_out = statistics[1]
    current_density = statistics[2]
    lye_flow = statistics[3]
    pressure = statistics[4]

    Vrev = Vrev_cal(lye_temp = lye_temp,
                    temp_out = temp_out,
                    pressure = pressure)
    
    # 避免 lye_temp 或 temp_out 为零
    lye_temp = torch.clamp(lye_temp, min=1e-10)
    temp_out = torch.clamp(temp_out, min=1e-10)

    lambda_flow = lye_flow / Volume_active / 0.51 - 12.37

    temp_work = (1 - lambda_flow) * lye_temp * c1 + lambda_flow * temp_out * c2
    
    # 避免 log 函数的负数输入
    log_input = torch.clamp((t1 + t2 / temp_work + t3 / temp_work ** 2) * current_density + 1, min=1e-10)

    Vcell = (r1 + r2 * temp_work) * current_density + s1 * torch.log(log_input) + Vrev
    
    return Vcell

# %% [markdown]
# ### 使用pytorch实现梯度下降优化

# %%
# 检查是否有 GPU 可用
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"使用设备: {device}")
# Out:
# 使用设备: cuda

# %% [markdown]
# #### 提取观测数据列

# %%
feature_cols = [Cols.lye_temp, Cols.temp_out, Cols.current_density, Cols.lye_flow, Cols.pressure]
target_cols = [Cols.cell_voltage]

statistics = df_static_XY[feature_cols]
cell_voltage_observed = df_static_XY[target_cols]

statistics_torch = torch.tensor(statistics.values.T, dtype=torch.float32)
cell_voltage_observed_torch = torch.tensor(cell_voltage_observed.values.T, dtype=torch.float32)

statistics_torch = statistics_torch.to(device)
cell_voltage_observed_torch = cell_voltage_observed_torch[0].to(device)

# 计算训练集和测试集的大小
total_size = statistics_torch.shape[1]
train_size = int(0.8 * total_size)
test_size = total_size - train_size


# 随机划分数据
train_indices, test_indices = random_split(range(total_size), [train_size, test_size])

# 根据划分的索引获取训练集和测试集
statistics_torch_train = statistics_torch[:, train_indices.indices]
cell_voltage_observed_torch_train = cell_voltage_observed_torch[train_indices.indices]

statistics_torch_test = statistics_torch[:, test_indices.indices]
cell_voltage_observed_torch_test = cell_voltage_observed_torch[test_indices.indices]

print(f"训练集大小: {statistics_torch_train.shape[1]}")
print(f"测试集大小: {statistics_torch_test.shape[1]}")
# Out:
# 训练集大小: 21714
# 测试集大小: 5429

# %% [markdown]
# #### 初始化需要拟合的参数（减小初始值范围）

# %%
# 直接赋值初始化
init_values = [8e-5, -9e-7, 2e-1, 1, 1e1, 1e2,
               1, 1
]
param_names = [
     'r1', 'r2', 's1', 't1', 't2', 't3',
     'c1', 'c2'
]

params = {name: torch.tensor([value], dtype=torch.float32, requires_grad = True) for name, value in zip(param_names, init_values)}
params = {k: torch.nn.Parameter(v.to(device)) for k, v in params.items()}

# %% [markdown]
# #### 训练

# %% [markdown]
# ##### 分学习率训练

# %%
# 定义损失函数
criterion = torch.nn.MSELoss()

# 分四类设置学习率
lr1 = 1e-9
lr2 = 1e-3
lr3 = 1e-2
lr4 = 1e-3

# 设置训练边界
tolerance = 1e-6

# 分离参数，按照不同学习率分类
paramsr_list = [params['r1'], params['r2']]
paramss_list = [params['s1'], params['t1'], params['t2']]
paramst_list = [params['t3']]
paramsc_list = [params['c1'], params['c2']]

# 使用单个优化器管理多参数组
optimizer = torch.optim.AdamW([
    {'params': paramsr_list, 'lr': lr1},
    {'params': paramss_list, 'lr': lr2},
    {'params': paramst_list, 'lr': lr3},
    {'params': paramsc_list, 'lr': lr4}
], weight_decay=1e-4)

# 早停策略参数
patience = 1000
best_test_loss = float('inf')
counter = 0

# 训练循环
num_epochs = 500000

for epoch in range(num_epochs):
    # 训练步骤
    optimizer.zero_grad()
    
    # 训练数据前向传播
    cell_voltage_pred_train = cell_voltage_cal_empirical_formula(statistics_torch_train, **params)
    train_loss = criterion(cell_voltage_pred_train, cell_voltage_observed_torch_train)
    
    # 反向传播与优化
    train_loss.backward()
    optimizer.step()
    
    # 验证步骤
    with torch.no_grad():
        cell_voltage_pred_test = cell_voltage_cal_empirical_formula(statistics_torch_test, **params)
        test_loss = criterion(cell_voltage_pred_test, cell_voltage_observed_torch_test)
    
    # 每50个epoch打印信息
    if epoch % 50 == 0:
        print(f'Epoch {epoch}, Train Loss: {train_loss.item():.4e}, test Loss: {test_loss.item():.4e}')
    
    # 早停策略
    if test_loss < best_test_loss:
        best_test_loss = test_loss
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}, best test loss: {best_test_loss:.4e}")
            break
    
    # 收敛条件检查
    if train_loss.item() < tolerance:
        print(f"训练损失达到收敛条件 (<{tolerance})")
        break

# 最终结果输出
print("训练完成，最终验证损失：", best_test_loss)
# Out:
# Epoch 0, Train Loss: 9.2096e-01, test Loss: 9.0495e-01
# Epoch 50, Train Loss: 3.2795e-01, test Loss: 3.2000e-01
# Epoch 100, Train Loss: 8.5885e-02, test Loss: 8.3177e-02
# Epoch 150, Train Loss: 1.6972e-02, test Loss: 1.6305e-02
# Epoch 200, Train Loss: 3.5939e-03, test Loss: 3.4622e-03
# Epoch 250, Train Loss: 1.8784e-03, test Loss: 1.8443e-03
# Epoch 300, Train Loss: 1.7312e-03, test Loss: 1.7112e-03
# Epoch 350, Train Loss: 1.7165e-03, test Loss: 1.6987e-03
# Epoch 400, Train Loss: 1.7081e-03, test Loss: 1.6907e-03
# Epoch 450, Train Loss: 1.6994e-03, test Loss: 1.6821e-03
# Epoch 500, Train Loss: 1.6902e-03, test Loss: 1.6729e-03
# Epoch 550, Train Loss: 1.6804e-03, test Loss: 1.6631e-03
# Epoch 600, Train Loss: 1.6701e-03, test Loss: 1.6530e-03
# Epoch 650, Train Loss: 1.6594e-03, test Loss: 1.6423e-03
# Epoch 700, Train Loss: 1.6482e-03, test Loss: 1.6312e-03
# Epoch 750, Train Loss: 1.6366e-03, test Loss: 1.6196e-03
# Epoch 800, Train Loss: 1.6245e-03, test Loss: 1.6076e-03
# Epoch 850, Train Loss: 1.6121e-03, test Loss: 1.5953e-03
# Epoch 900, Train Loss: 1.5992e-03, test Loss: 1.5825e-03
# Epoch 950, Train Loss: 1.5860e-03, test Loss: 1.5693e-03
# Epoch 1000, Train Loss: 1.5724e-03, test Loss: 1.5559e-03
# Epoch 1050, Train Loss: 1.5584e-03, test Loss: 1.5420e-03
# Epoch 1100, Train Loss: 1.5441e-03, test Loss: 1.5278e-03
# Epoch 1150, Train Loss: 1.5295e-03, test Loss: 1.5133e-03
# Epoch 1200, Train Loss: 1.5146e-03, test Loss: 1.4985e-03
# Epoch 1250, Train Loss: 1.4994e-03, test Loss: 1.4834e-03
# Epoch 1300, Train Loss: 1.4839e-03, test Loss: 1.4681e-03
# Epoch 1350, Train Loss: 1.4682e-03, test Loss: 1.4524e-03
# Epoch 1400, Train Loss: 1.4522e-03, test Loss: 1.4365e-03
# Epoch 1450, Train Loss: 1.4359e-03, test Loss: 1.4204e-03
# Epoch 1500, Train Loss: 1.4194e-03, test Loss: 1.4040e-03
# Epoch 1550, Train Loss: 1.4027e-03, test Loss: 1.3874e-03
# Epoch 1600, Train Loss: 1.3858e-03, test Loss: 1.3706e-03
# Epoch 1650, Train Loss: 1.3687e-03, test Loss: 1.3536e-03
# Epoch 1700, Train Loss: 1.3514e-03, test Loss: 1.3365e-03
# Epoch 1750, Train Loss: 1.3339e-03, test Loss: 1.3192e-03
# Epoch 1800, Train Loss: 1.3163e-03, test Loss: 1.3017e-03
# Epoch 1850, Train Loss: 1.2986e-03, test Loss: 1.2841e-03
# Epoch 1900, Train Loss: 1.2807e-03, test Loss: 1.2663e-03
# Epoch 1950, Train Loss: 1.2627e-03, test Loss: 1.2485e-03
# Epoch 2000, Train Loss: 1.2446e-03, test Loss: 1.2305e-03
# Epoch 2050, Train Loss: 1.2264e-03, test Loss: 1.2125e-03
# Epoch 2100, Train Loss: 1.2081e-03, test Loss: 1.1943e-03
# Epoch 2150, Train Loss: 1.1898e-03, test Loss: 1.1761e-03
# Epoch 2200, Train Loss: 1.1714e-03, test Loss: 1.1579e-03
# Epoch 2250, Train Loss: 1.1529e-03, test Loss: 1.1396e-03
# Epoch 2300, Train Loss: 1.1345e-03, test Loss: 1.1213e-03
# Epoch 2350, Train Loss: 1.1160e-03, test Loss: 1.1029e-03
# Epoch 2400, Train Loss: 1.0975e-03, test Loss: 1.0846e-03
# Epoch 2450, Train Loss: 1.0790e-03, test Loss: 1.0662e-03
# Epoch 2500, Train Loss: 1.0605e-03, test Loss: 1.0479e-03
# Epoch 2550, Train Loss: 1.0420e-03, test Loss: 1.0296e-03
# Epoch 2600, Train Loss: 1.0236e-03, test Loss: 1.0113e-03
# Epoch 2650, Train Loss: 1.0053e-03, test Loss: 9.9310e-04
# Epoch 2700, Train Loss: 9.8695e-04, test Loss: 9.7493e-04
# Epoch 2750, Train Loss: 9.6871e-04, test Loss: 9.5684e-04
# Epoch 2800, Train Loss: 9.5055e-04, test Loss: 9.3884e-04
# Epoch 2850, Train Loss: 9.3248e-04, test Loss: 9.2091e-04
# Epoch 2900, Train Loss: 9.1450e-04, test Loss: 9.0308e-04
# Epoch 2950, Train Loss: 8.9663e-04, test Loss: 8.8537e-04
# Epoch 3000, Train Loss: 8.7888e-04, test Loss: 8.6777e-04
# Epoch 3050, Train Loss: 8.6125e-04, test Loss: 8.5029e-04
# Epoch 3100, Train Loss: 8.4376e-04, test Loss: 8.3295e-04
# Epoch 3150, Train Loss: 8.2641e-04, test Loss: 8.1574e-04
# Epoch 3200, Train Loss: 8.0920e-04, test Loss: 7.9869e-04
# Epoch 3250, Train Loss: 7.9216e-04, test Loss: 7.8179e-04
# Epoch 3300, Train Loss: 7.7527e-04, test Loss: 7.6505e-04
# Epoch 3350, Train Loss: 7.5856e-04, test Loss: 7.4848e-04
# Epoch 3400, Train Loss: 7.4202e-04, test Loss: 7.3209e-04
# Epoch 3450, Train Loss: 7.2567e-04, test Loss: 7.1589e-04
# Epoch 3500, Train Loss: 7.0951e-04, test Loss: 6.9987e-04
# Epoch 3550, Train Loss: 6.9354e-04, test Loss: 6.8404e-04
# Epoch 3600, Train Loss: 6.7777e-04, test Loss: 6.6841e-04
# Epoch 3650, Train Loss: 6.6221e-04, test Loss: 6.5299e-04
# Epoch 3700, Train Loss: 6.4685e-04, test Loss: 6.3777e-04
# Epoch 3750, Train Loss: 6.3170e-04, test Loss: 6.2276e-04
# Epoch 3800, Train Loss: 6.1678e-04, test Loss: 6.0797e-04
# Epoch 3850, Train Loss: 6.0207e-04, test Loss: 5.9339e-04
# Epoch 3900, Train Loss: 5.8758e-04, test Loss: 5.7904e-04
# Epoch 3950, Train Loss: 5.7332e-04, test Loss: 5.6491e-04
# Epoch 4000, Train Loss: 5.5928e-04, test Loss: 5.5100e-04
# Epoch 4050, Train Loss: 5.4547e-04, test Loss: 5.3733e-04
# Epoch 4100, Train Loss: 5.3190e-04, test Loss: 5.2388e-04
# Epoch 4150, Train Loss: 5.1856e-04, test Loss: 5.1067e-04
# Epoch 4200, Train Loss: 5.0545e-04, test Loss: 4.9768e-04
# Epoch 4250, Train Loss: 4.9258e-04, test Loss: 4.8493e-04
# Epoch 4300, Train Loss: 4.7995e-04, test Loss: 4.7242e-04
# Epoch 4350, Train Loss: 4.6755e-04, test Loss: 4.6014e-04
# Epoch 4400, Train Loss: 4.5539e-04, test Loss: 4.4809e-04
# Epoch 4450, Train Loss: 4.4346e-04, test Loss: 4.3628e-04
# Epoch 4500, Train Loss: 4.3177e-04, test Loss: 4.2471e-04
# Epoch 4550, Train Loss: 4.2032e-04, test Loss: 4.1337e-04
# Epoch 4600, Train Loss: 4.0910e-04, test Loss: 4.0226e-04
# Epoch 4650, Train Loss: 3.9811e-04, test Loss: 3.9138e-04
# Epoch 4700, Train Loss: 3.8736e-04, test Loss: 3.8074e-04
# Epoch 4750, Train Loss: 3.7685e-04, test Loss: 3.7032e-04
# Epoch 4800, Train Loss: 3.6655e-04, test Loss: 3.6014e-04
# Epoch 4850, Train Loss: 3.5649e-04, test Loss: 3.5018e-04
# Epoch 4900, Train Loss: 3.4666e-04, test Loss: 3.4044e-04
# Epoch 4950, Train Loss: 3.3706e-04, test Loss: 3.3093e-04
# Epoch 5000, Train Loss: 3.2767e-04, test Loss: 3.2164e-04
# Epoch 5050, Train Loss: 3.1851e-04, test Loss: 3.1257e-04
# Epoch 5100, Train Loss: 3.0956e-04, test Loss: 3.0372e-04
# Epoch 5150, Train Loss: 3.0083e-04, test Loss: 2.9508e-04
# Epoch 5200, Train Loss: 2.9232e-04, test Loss: 2.8666e-04
# Epoch 5250, Train Loss: 2.8402e-04, test Loss: 2.7845e-04
# Epoch 5300, Train Loss: 2.7593e-04, test Loss: 2.7044e-04
# Epoch 5350, Train Loss: 2.6805e-04, test Loss: 2.6264e-04
# Epoch 5400, Train Loss: 2.6037e-04, test Loss: 2.5505e-04
# Epoch 5450, Train Loss: 2.5289e-04, test Loss: 2.4765e-04
# Epoch 5500, Train Loss: 2.4562e-04, test Loss: 2.4046e-04
# Epoch 5550, Train Loss: 2.3855e-04, test Loss: 2.3346e-04
# Epoch 5600, Train Loss: 2.3167e-04, test Loss: 2.2666e-04
# Epoch 5650, Train Loss: 2.2498e-04, test Loss: 2.2005e-04
# Epoch 5700, Train Loss: 2.1848e-04, test Loss: 2.1362e-04
# Epoch 5750, Train Loss: 2.1217e-04, test Loss: 2.0738e-04
# Epoch 5800, Train Loss: 2.0605e-04, test Loss: 2.0133e-04
# Epoch 5850, Train Loss: 2.0011e-04, test Loss: 1.9546e-04
# Epoch 5900, Train Loss: 1.9435e-04, test Loss: 1.8977e-04
# Epoch 5950, Train Loss: 1.8878e-04, test Loss: 1.8426e-04
# Epoch 6000, Train Loss: 1.8338e-04, test Loss: 1.7893e-04
# Epoch 6050, Train Loss: 1.7816e-04, test Loss: 1.7377e-04
# Epoch 6100, Train Loss: 1.7312e-04, test Loss: 1.6879e-04
# Epoch 6150, Train Loss: 1.6825e-04, test Loss: 1.6398e-04
# Epoch 6200, Train Loss: 1.6355e-04, test Loss: 1.5934e-04
# Epoch 6250, Train Loss: 1.5902e-04, test Loss: 1.5488e-04
# Epoch 6300, Train Loss: 1.5467e-04, test Loss: 1.5058e-04
# Epoch 6350, Train Loss: 1.5049e-04, test Loss: 1.4646e-04
# Epoch 6400, Train Loss: 1.4647e-04, test Loss: 1.4249e-04
# Epoch 6450, Train Loss: 1.4261e-04, test Loss: 1.3870e-04
# Epoch 6500, Train Loss: 1.3893e-04, test Loss: 1.3506e-04
# Epoch 6550, Train Loss: 1.3540e-04, test Loss: 1.3159e-04
# Epoch 6600, Train Loss: 1.3204e-04, test Loss: 1.2828e-04
# Epoch 6650, Train Loss: 1.2884e-04, test Loss: 1.2514e-04
# Epoch 6700, Train Loss: 1.2580e-04, test Loss: 1.2214e-04
# Epoch 6750, Train Loss: 1.2291e-04, test Loss: 1.1931e-04
# Epoch 6800, Train Loss: 1.2018e-04, test Loss: 1.1663e-04
# Epoch 6850, Train Loss: 1.1761e-04, test Loss: 1.1410e-04
# Epoch 6900, Train Loss: 1.1518e-04, test Loss: 1.1172e-04
# Epoch 6950, Train Loss: 1.1289e-04, test Loss: 1.0948e-04
# Epoch 7000, Train Loss: 1.1075e-04, test Loss: 1.0738e-04
# Epoch 7050, Train Loss: 1.0874e-04, test Loss: 1.0542e-04
# Epoch 7100, Train Loss: 1.0686e-04, test Loss: 1.0358e-04
# Epoch 7150, Train Loss: 1.0511e-04, test Loss: 1.0187e-04
# Epoch 7200, Train Loss: 1.0347e-04, test Loss: 1.0027e-04
# Epoch 7250, Train Loss: 1.0195e-04, test Loss: 9.8790e-05
# Epoch 7300, Train Loss: 1.0053e-04, test Loss: 9.7406e-05
# Epoch 7350, Train Loss: 9.9202e-05, test Loss: 9.6116e-05
# Epoch 7400, Train Loss: 9.7963e-05, test Loss: 9.4911e-05
# Epoch 7450, Train Loss: 9.6804e-05, test Loss: 9.3785e-05
# Epoch 7500, Train Loss: 9.5714e-05, test Loss: 9.2727e-05
# Epoch 7550, Train Loss: 9.4687e-05, test Loss: 9.1729e-05
# Epoch 7600, Train Loss: 9.3714e-05, test Loss: 9.0783e-05
# Epoch 7650, Train Loss: 9.2787e-05, test Loss: 8.9882e-05
# Epoch 7700, Train Loss: 9.1900e-05, test Loss: 8.9019e-05
# Epoch 7750, Train Loss: 9.1046e-05, test Loss: 8.8188e-05
# Epoch 7800, Train Loss: 9.0219e-05, test Loss: 8.7382e-05
# Epoch 7850, Train Loss: 8.9415e-05, test Loss: 8.6597e-05
# Epoch 7900, Train Loss: 8.8628e-05, test Loss: 8.5829e-05
# Epoch 7950, Train Loss: 8.7855e-05, test Loss: 8.5073e-05
# Epoch 8000, Train Loss: 8.7093e-05, test Loss: 8.4326e-05
# Epoch 8050, Train Loss: 8.6338e-05, test Loss: 8.3586e-05
# Epoch 8100, Train Loss: 8.5589e-05, test Loss: 8.2850e-05
# Epoch 8150, Train Loss: 8.4844e-05, test Loss: 8.2117e-05
# Epoch 8200, Train Loss: 8.4102e-05, test Loss: 8.1386e-05
# Epoch 8250, Train Loss: 8.3360e-05, test Loss: 8.0656e-05
# Epoch 8300, Train Loss: 8.2620e-05, test Loss: 7.9926e-05
# Epoch 8350, Train Loss: 8.1880e-05, test Loss: 7.9195e-05
# Epoch 8400, Train Loss: 8.1140e-05, test Loss: 7.8464e-05
# Epoch 8450, Train Loss: 8.0399e-05, test Loss: 7.7732e-05
# Epoch 8500, Train Loss: 7.9658e-05, test Loss: 7.6999e-05
# Epoch 8550, Train Loss: 7.8917e-05, test Loss: 7.6266e-05
# Epoch 8600, Train Loss: 7.8175e-05, test Loss: 7.5531e-05
# Epoch 8650, Train Loss: 7.7433e-05, test Loss: 7.4796e-05
# Epoch 8700, Train Loss: 7.6690e-05, test Loss: 7.4061e-05
# Epoch 8750, Train Loss: 7.5948e-05, test Loss: 7.3325e-05
# Epoch 8800, Train Loss: 7.5205e-05, test Loss: 7.2590e-05
# Epoch 8850, Train Loss: 7.4463e-05, test Loss: 7.1854e-05
# Epoch 8900, Train Loss: 7.3721e-05, test Loss: 7.1119e-05
# Epoch 8950, Train Loss: 7.2979e-05, test Loss: 7.0384e-05
# Epoch 9000, Train Loss: 7.2238e-05, test Loss: 6.9649e-05
# Epoch 9050, Train Loss: 7.1498e-05, test Loss: 6.8916e-05
# Epoch 9100, Train Loss: 7.0760e-05, test Loss: 6.8183e-05
# Epoch 9150, Train Loss: 7.0022e-05, test Loss: 6.7452e-05
# Epoch 9200, Train Loss: 6.9286e-05, test Loss: 6.6721e-05
# Epoch 9250, Train Loss: 6.8551e-05, test Loss: 6.5993e-05
# Epoch 9300, Train Loss: 6.7818e-05, test Loss: 6.5266e-05
# Epoch 9350, Train Loss: 6.7087e-05, test Loss: 6.4541e-05
# Epoch 9400, Train Loss: 6.6358e-05, test Loss: 6.3817e-05
# Epoch 9450, Train Loss: 6.5631e-05, test Loss: 6.3096e-05
# Epoch 9500, Train Loss: 6.4906e-05, test Loss: 6.2377e-05
# Epoch 9550, Train Loss: 6.4183e-05, test Loss: 6.1660e-05
# Epoch 9600, Train Loss: 6.3463e-05, test Loss: 6.0946e-05
# Epoch 9650, Train Loss: 6.2746e-05, test Loss: 6.0234e-05
# Epoch 9700, Train Loss: 6.2031e-05, test Loss: 5.9525e-05
# Epoch 9750, Train Loss: 6.1320e-05, test Loss: 5.8819e-05
# Epoch 9800, Train Loss: 6.0611e-05, test Loss: 5.8115e-05
# Epoch 9850, Train Loss: 5.9905e-05, test Loss: 5.7415e-05
# Epoch 9900, Train Loss: 5.9203e-05, test Loss: 5.6717e-05
# Epoch 9950, Train Loss: 5.8503e-05, test Loss: 5.6023e-05
# Epoch 10000, Train Loss: 5.7807e-05, test Loss: 5.5332e-05
# Epoch 10050, Train Loss: 5.7114e-05, test Loss: 5.4644e-05
# Epoch 10100, Train Loss: 5.6425e-05, test Loss: 5.3960e-05
# Epoch 10150, Train Loss: 5.5739e-05, test Loss: 5.3278e-05
# Epoch 10200, Train Loss: 5.5056e-05, test Loss: 5.2601e-05
# Epoch 10250, Train Loss: 5.4377e-05, test Loss: 5.1926e-05
# Epoch 10300, Train Loss: 5.3702e-05, test Loss: 5.1255e-05
# Epoch 10350, Train Loss: 5.3030e-05, test Loss: 5.0588e-05
# Epoch 10400, Train Loss: 5.2362e-05, test Loss: 4.9924e-05
# Epoch 10450, Train Loss: 5.1697e-05, test Loss: 4.9263e-05
# Epoch 10500, Train Loss: 5.1035e-05, test Loss: 4.8606e-05
# Epoch 10550, Train Loss: 5.0377e-05, test Loss: 4.7952e-05
# Epoch 10600, Train Loss: 4.9723e-05, test Loss: 4.7301e-05
# Epoch 10650, Train Loss: 4.9072e-05, test Loss: 4.6654e-05
# Epoch 10700, Train Loss: 4.8425e-05, test Loss: 4.6010e-05
# Epoch 10750, Train Loss: 4.7781e-05, test Loss: 4.5370e-05
# Epoch 10800, Train Loss: 4.7140e-05, test Loss: 4.4733e-05
# Epoch 10850, Train Loss: 4.6503e-05, test Loss: 4.4099e-05
# Epoch 10900, Train Loss: 4.5868e-05, test Loss: 4.3467e-05
# Epoch 10950, Train Loss: 4.5237e-05, test Loss: 4.2839e-05
# Epoch 11000, Train Loss: 4.4610e-05, test Loss: 4.2215e-05
# Epoch 11050, Train Loss: 4.3985e-05, test Loss: 4.1592e-05
# Epoch 11100, Train Loss: 4.3363e-05, test Loss: 4.0973e-05
# Epoch 11150, Train Loss: 4.2745e-05, test Loss: 4.0357e-05
# Epoch 11200, Train Loss: 4.2129e-05, test Loss: 3.9744e-05
# Epoch 11250, Train Loss: 4.1517e-05, test Loss: 3.9133e-05
# Epoch 11300, Train Loss: 4.0907e-05, test Loss: 3.8525e-05
# Epoch 11350, Train Loss: 4.0301e-05, test Loss: 3.7920e-05
# Epoch 11400, Train Loss: 3.9698e-05, test Loss: 3.7318e-05
# Epoch 11450, Train Loss: 3.9099e-05, test Loss: 3.6719e-05
# Epoch 11500, Train Loss: 3.8504e-05, test Loss: 3.6125e-05
# Epoch 11550, Train Loss: 3.7912e-05, test Loss: 3.5534e-05
# Epoch 11600, Train Loss: 3.7326e-05, test Loss: 3.4947e-05
# Epoch 11650, Train Loss: 3.6744e-05, test Loss: 3.4364e-05
# Epoch 11700, Train Loss: 3.6168e-05, test Loss: 3.3787e-05
# Epoch 11750, Train Loss: 3.5599e-05, test Loss: 3.3216e-05
# Epoch 11800, Train Loss: 3.5036e-05, test Loss: 3.2652e-05
# Epoch 11850, Train Loss: 3.4482e-05, test Loss: 3.2096e-05
# Epoch 11900, Train Loss: 3.3938e-05, test Loss: 3.1548e-05
# Epoch 11950, Train Loss: 3.3404e-05, test Loss: 3.1011e-05
# Epoch 12000, Train Loss: 3.2883e-05, test Loss: 3.0485e-05
# Epoch 12050, Train Loss: 3.2376e-05, test Loss: 2.9973e-05
# Epoch 12100, Train Loss: 3.1885e-05, test Loss: 2.9477e-05
# Epoch 12150, Train Loss: 3.1412e-05, test Loss: 2.8997e-05
# Epoch 12200, Train Loss: 3.0958e-05, test Loss: 2.8536e-05
# Epoch 12250, Train Loss: 3.0526e-05, test Loss: 2.8096e-05
# Epoch 12300, Train Loss: 3.0117e-05, test Loss: 2.7679e-05
# Epoch 12350, Train Loss: 2.9734e-05, test Loss: 2.7287e-05
# Epoch 12400, Train Loss: 2.9378e-05, test Loss: 2.6921e-05
# Epoch 12450, Train Loss: 2.9049e-05, test Loss: 2.6582e-05
# Epoch 12500, Train Loss: 2.8750e-05, test Loss: 2.6272e-05
# Epoch 12550, Train Loss: 2.8479e-05, test Loss: 2.5990e-05
# Epoch 12600, Train Loss: 2.8237e-05, test Loss: 2.5736e-05
# Epoch 12650, Train Loss: 2.8023e-05, test Loss: 2.5511e-05
# Epoch 12700, Train Loss: 2.7835e-05, test Loss: 2.5312e-05
# Epoch 12750, Train Loss: 2.7673e-05, test Loss: 2.5138e-05
# Epoch 12800, Train Loss: 2.7534e-05, test Loss: 2.4987e-05
# Epoch 12850, Train Loss: 2.7415e-05, test Loss: 2.4857e-05
# Epoch 12900, Train Loss: 2.7314e-05, test Loss: 2.4746e-05
# Epoch 12950, Train Loss: 2.7229e-05, test Loss: 2.4651e-05
# Epoch 13000, Train Loss: 2.7157e-05, test Loss: 2.4570e-05
# Epoch 13050, Train Loss: 2.7097e-05, test Loss: 2.4501e-05
# Epoch 13100, Train Loss: 2.7046e-05, test Loss: 2.4442e-05
# Epoch 13150, Train Loss: 2.7002e-05, test Loss: 2.4391e-05
# Epoch 13200, Train Loss: 2.6964e-05, test Loss: 2.4347e-05
# Epoch 13250, Train Loss: 2.6931e-05, test Loss: 2.4308e-05
# Epoch 13300, Train Loss: 2.6902e-05, test Loss: 2.4273e-05
# Epoch 13350, Train Loss: 2.6876e-05, test Loss: 2.4242e-05
# Epoch 13400, Train Loss: 2.6852e-05, test Loss: 2.4214e-05
# Epoch 13450, Train Loss: 2.6831e-05, test Loss: 2.4188e-05
# Epoch 13500, Train Loss: 2.6810e-05, test Loss: 2.4165e-05
# Epoch 13550, Train Loss: 2.6791e-05, test Loss: 2.4143e-05
# Epoch 13600, Train Loss: 2.6774e-05, test Loss: 2.4122e-05
# Epoch 13650, Train Loss: 2.6757e-05, test Loss: 2.4102e-05
# Epoch 13700, Train Loss: 2.6740e-05, test Loss: 2.4083e-05
# Epoch 13750, Train Loss: 2.6725e-05, test Loss: 2.4065e-05
# Epoch 13800, Train Loss: 2.6710e-05, test Loss: 2.4048e-05
# Epoch 13850, Train Loss: 2.6695e-05, test Loss: 2.4031e-05
# Epoch 13900, Train Loss: 2.6681e-05, test Loss: 2.4015e-05
# Epoch 13950, Train Loss: 2.6667e-05, test Loss: 2.4000e-05
# Epoch 14000, Train Loss: 2.6653e-05, test Loss: 2.3984e-05
# Epoch 14050, Train Loss: 2.7781e-05, test Loss: 2.5203e-05
# Epoch 14100, Train Loss: 2.6631e-05, test Loss: 2.3968e-05
# Epoch 14150, Train Loss: 2.6615e-05, test Loss: 2.3941e-05
# Epoch 14200, Train Loss: 2.6603e-05, test Loss: 2.3927e-05
# Epoch 14250, Train Loss: 2.6591e-05, test Loss: 2.3914e-05
# Epoch 14300, Train Loss: 2.6608e-05, test Loss: 2.3877e-05
# Epoch 14350, Train Loss: 2.6570e-05, test Loss: 2.3893e-05
# Epoch 14400, Train Loss: 2.6557e-05, test Loss: 2.3874e-05
# Epoch 14450, Train Loss: 2.6546e-05, test Loss: 2.3863e-05
# Epoch 14500, Train Loss: 2.6535e-05, test Loss: 2.3851e-05
# Epoch 14550, Train Loss: 2.6525e-05, test Loss: 2.3840e-05
# Epoch 14600, Train Loss: 2.6649e-05, test Loss: 2.3803e-05
# Epoch 14650, Train Loss: 2.6505e-05, test Loss: 2.3824e-05
# Epoch 14700, Train Loss: 2.6495e-05, test Loss: 2.3806e-05
# Epoch 14750, Train Loss: 2.6485e-05, test Loss: 2.3795e-05
# Epoch 14800, Train Loss: 2.6477e-05, test Loss: 2.3795e-05
# Epoch 14850, Train Loss: 2.6469e-05, test Loss: 2.3759e-05
# Epoch 14900, Train Loss: 2.6459e-05, test Loss: 2.3770e-05
# Epoch 14950, Train Loss: 2.6450e-05, test Loss: 2.3756e-05
# Epoch 15000, Train Loss: 2.6442e-05, test Loss: 2.3747e-05
# Epoch 15050, Train Loss: 2.6439e-05, test Loss: 2.3835e-05
# Epoch 15100, Train Loss: 2.6428e-05, test Loss: 2.3737e-05
# Epoch 15150, Train Loss: 2.6420e-05, test Loss: 2.3723e-05
# Epoch 15200, Train Loss: 2.6413e-05, test Loss: 2.3715e-05
# Epoch 15250, Train Loss: 2.6407e-05, test Loss: 2.3709e-05
# Epoch 15300, Train Loss: 2.6402e-05, test Loss: 2.3671e-05
# Epoch 15350, Train Loss: 2.6395e-05, test Loss: 2.3687e-05
# Epoch 15400, Train Loss: 2.6389e-05, test Loss: 2.3689e-05
# Epoch 15450, Train Loss: 2.6384e-05, test Loss: 2.3683e-05
# Epoch 15500, Train Loss: 2.6380e-05, test Loss: 2.3694e-05
# Epoch 15550, Train Loss: 2.6376e-05, test Loss: 2.3695e-05
# Epoch 15600, Train Loss: 2.6370e-05, test Loss: 2.3669e-05
# Epoch 15650, Train Loss: 2.6366e-05, test Loss: 2.3664e-05
# Epoch 15700, Train Loss: 2.6362e-05, test Loss: 2.3659e-05
# Epoch 15750, Train Loss: 2.6382e-05, test Loss: 2.3763e-05
# Epoch 15800, Train Loss: 2.6371e-05, test Loss: 2.3624e-05
# Epoch 15850, Train Loss: 2.6352e-05, test Loss: 2.3646e-05
# Epoch 15900, Train Loss: 2.6348e-05, test Loss: 2.3645e-05
# Epoch 15950, Train Loss: 2.6346e-05, test Loss: 2.3642e-05
# Epoch 16000, Train Loss: 2.6343e-05, test Loss: 2.3642e-05
# Epoch 16050, Train Loss: 2.6413e-05, test Loss: 2.3610e-05
# Epoch 16100, Train Loss: 2.6338e-05, test Loss: 2.3637e-05
# Epoch 16150, Train Loss: 2.6335e-05, test Loss: 2.3632e-05
# Epoch 16200, Train Loss: 2.6333e-05, test Loss: 2.3629e-05
# Epoch 16250, Train Loss: 2.6331e-05, test Loss: 2.3627e-05
# Epoch 16300, Train Loss: 2.6493e-05, test Loss: 2.3713e-05
# Epoch 16350, Train Loss: 2.6329e-05, test Loss: 2.3601e-05
# Epoch 16400, Train Loss: 2.6326e-05, test Loss: 2.3619e-05
# Epoch 16450, Train Loss: 2.6324e-05, test Loss: 2.3620e-05
# Epoch 16500, Train Loss: 2.6322e-05, test Loss: 2.3618e-05
# Epoch 16550, Train Loss: 2.6351e-05, test Loss: 2.3740e-05
# Epoch 16600, Train Loss: 2.6327e-05, test Loss: 2.3629e-05
# Epoch 16650, Train Loss: 2.6317e-05, test Loss: 2.3614e-05
# Epoch 16700, Train Loss: 2.6316e-05, test Loss: 2.3612e-05
# Epoch 16750, Train Loss: 2.6315e-05, test Loss: 2.3611e-05
# Epoch 16800, Train Loss: 2.6498e-05, test Loss: 2.3705e-05
# Epoch 16850, Train Loss: 2.6313e-05, test Loss: 2.3603e-05
# Epoch 16900, Train Loss: 2.6311e-05, test Loss: 2.3606e-05
# Epoch 16950, Train Loss: 2.6309e-05, test Loss: 2.3606e-05
# Epoch 17000, Train Loss: 2.6308e-05, test Loss: 2.3605e-05
# Epoch 17050, Train Loss: 2.7458e-05, test Loss: 2.4663e-05
# Epoch 17100, Train Loss: 2.6306e-05, test Loss: 2.3589e-05
# Epoch 17150, Train Loss: 2.6304e-05, test Loss: 2.3602e-05
# Epoch 17200, Train Loss: 2.6303e-05, test Loss: 2.3600e-05
# Epoch 17250, Train Loss: 2.6302e-05, test Loss: 2.3599e-05
# Epoch 17300, Train Loss: 2.6414e-05, test Loss: 2.3633e-05
# Epoch 17350, Train Loss: 2.6304e-05, test Loss: 2.3620e-05
# Epoch 17400, Train Loss: 2.6298e-05, test Loss: 2.3596e-05
# Epoch 17450, Train Loss: 2.6297e-05, test Loss: 2.3594e-05
# Epoch 17500, Train Loss: 2.6296e-05, test Loss: 2.3593e-05
# Epoch 17550, Train Loss: 2.6563e-05, test Loss: 2.3843e-05
# Epoch 17600, Train Loss: 2.6295e-05, test Loss: 2.3590e-05
# Epoch 17650, Train Loss: 2.6293e-05, test Loss: 2.3589e-05
# Epoch 17700, Train Loss: 2.6292e-05, test Loss: 2.3589e-05
# Epoch 17750, Train Loss: 2.6290e-05, test Loss: 2.3588e-05
# Epoch 17800, Train Loss: 2.7709e-05, test Loss: 2.4093e-05
# Epoch 17850, Train Loss: 2.6288e-05, test Loss: 2.3569e-05
# Epoch 17900, Train Loss: 2.6287e-05, test Loss: 2.3585e-05
# Epoch 17950, Train Loss: 2.6286e-05, test Loss: 2.3583e-05
# Epoch 18000, Train Loss: 2.6285e-05, test Loss: 2.3582e-05
# Epoch 18050, Train Loss: 2.6284e-05, test Loss: 2.3581e-05
# Epoch 18100, Train Loss: 2.8126e-05, test Loss: 2.5836e-05
# Epoch 18150, Train Loss: 2.6290e-05, test Loss: 2.3613e-05
# Epoch 18200, Train Loss: 2.6280e-05, test Loss: 2.3580e-05
# Epoch 18250, Train Loss: 2.6279e-05, test Loss: 2.3577e-05
# Epoch 18300, Train Loss: 2.6278e-05, test Loss: 2.3576e-05
# Epoch 18350, Train Loss: 2.6277e-05, test Loss: 2.3575e-05
# Epoch 18400, Train Loss: 2.6276e-05, test Loss: 2.3571e-05
# Epoch 18450, Train Loss: 2.6302e-05, test Loss: 2.3718e-05
# Epoch 18500, Train Loss: 2.6274e-05, test Loss: 2.3566e-05
# Epoch 18550, Train Loss: 2.6273e-05, test Loss: 2.3571e-05
# Epoch 18600, Train Loss: 2.6272e-05, test Loss: 2.3570e-05
# Epoch 18650, Train Loss: 2.6270e-05, test Loss: 2.3568e-05
# Epoch 18700, Train Loss: 2.6635e-05, test Loss: 2.4446e-05
# Epoch 18750, Train Loss: 2.6279e-05, test Loss: 2.3541e-05
# Epoch 18800, Train Loss: 2.6267e-05, test Loss: 2.3566e-05
# Epoch 18850, Train Loss: 2.6266e-05, test Loss: 2.3564e-05
# Epoch 18900, Train Loss: 2.6265e-05, test Loss: 2.3563e-05
# Epoch 18950, Train Loss: 2.6264e-05, test Loss: 2.3562e-05
# Epoch 19000, Train Loss: 2.6342e-05, test Loss: 2.3564e-05
# Epoch 19050, Train Loss: 2.6274e-05, test Loss: 2.3606e-05
# Epoch 19100, Train Loss: 2.6261e-05, test Loss: 2.3560e-05
# Epoch 19150, Train Loss: 2.6259e-05, test Loss: 2.3557e-05
# Epoch 19200, Train Loss: 2.6258e-05, test Loss: 2.3556e-05
# Epoch 19250, Train Loss: 2.7627e-05, test Loss: 2.4227e-05
# Epoch 19300, Train Loss: 2.6262e-05, test Loss: 2.3584e-05
# Epoch 19350, Train Loss: 2.6255e-05, test Loss: 2.3555e-05
# Epoch 19400, Train Loss: 2.6254e-05, test Loss: 2.3552e-05
# Epoch 19450, Train Loss: 2.6253e-05, test Loss: 2.3551e-05
# Epoch 19500, Train Loss: 2.6253e-05, test Loss: 2.3567e-05
# Epoch 19550, Train Loss: 2.6264e-05, test Loss: 2.3633e-05
# Epoch 19600, Train Loss: 2.6249e-05, test Loss: 2.3552e-05
# Epoch 19650, Train Loss: 2.6248e-05, test Loss: 2.3546e-05
# Epoch 19700, Train Loss: 2.6247e-05, test Loss: 2.3545e-05
# Epoch 19750, Train Loss: 2.6247e-05, test Loss: 2.3557e-05
# Epoch 19800, Train Loss: 2.6269e-05, test Loss: 2.3523e-05
# Epoch 19850, Train Loss: 2.6244e-05, test Loss: 2.3538e-05
# Epoch 19900, Train Loss: 2.6243e-05, test Loss: 2.3541e-05
# Epoch 19950, Train Loss: 2.6241e-05, test Loss: 2.3540e-05
# Epoch 20000, Train Loss: 2.6397e-05, test Loss: 2.3617e-05
# Epoch 20050, Train Loss: 2.6242e-05, test Loss: 2.3536e-05
# Epoch 20100, Train Loss: 2.6238e-05, test Loss: 2.3538e-05
# Epoch 20150, Train Loss: 2.6237e-05, test Loss: 2.3535e-05
# Epoch 20200, Train Loss: 2.6236e-05, test Loss: 2.3534e-05
# Epoch 20250, Train Loss: 2.6278e-05, test Loss: 2.3513e-05
# Epoch 20300, Train Loss: 2.6237e-05, test Loss: 2.3506e-05
# Epoch 20350, Train Loss: 2.6232e-05, test Loss: 2.3533e-05
# Epoch 20400, Train Loss: 2.6231e-05, test Loss: 2.3529e-05
# Epoch 20450, Train Loss: 2.6230e-05, test Loss: 2.3529e-05
# Epoch 20500, Train Loss: 2.6229e-05, test Loss: 2.3528e-05
# Epoch 20550, Train Loss: 2.6253e-05, test Loss: 2.3815e-05
# Epoch 20600, Train Loss: 2.6229e-05, test Loss: 2.3539e-05
# Epoch 20650, Train Loss: 2.6226e-05, test Loss: 2.3523e-05
# Epoch 20700, Train Loss: 2.6224e-05, test Loss: 2.3523e-05
# Epoch 20750, Train Loss: 2.6223e-05, test Loss: 2.3522e-05
# Epoch 20800, Train Loss: 2.6297e-05, test Loss: 2.3537e-05
# Epoch 20850, Train Loss: 2.6222e-05, test Loss: 2.3507e-05
# Epoch 20900, Train Loss: 2.6220e-05, test Loss: 2.3518e-05
# Epoch 20950, Train Loss: 2.6219e-05, test Loss: 2.3518e-05
# Epoch 21000, Train Loss: 2.6218e-05, test Loss: 2.3516e-05
# Epoch 21050, Train Loss: 2.6217e-05, test Loss: 2.3530e-05
# Epoch 21100, Train Loss: 2.6227e-05, test Loss: 2.3509e-05
# Epoch 21150, Train Loss: 2.6214e-05, test Loss: 2.3511e-05
# Epoch 21200, Train Loss: 2.6213e-05, test Loss: 2.3512e-05
# Epoch 21250, Train Loss: 2.6212e-05, test Loss: 2.3511e-05
# Epoch 21300, Train Loss: 2.6357e-05, test Loss: 2.3575e-05
# Epoch 21350, Train Loss: 2.6215e-05, test Loss: 2.3517e-05
# Epoch 21400, Train Loss: 2.6209e-05, test Loss: 2.3510e-05
# Epoch 21450, Train Loss: 2.6207e-05, test Loss: 2.3506e-05
# Epoch 21500, Train Loss: 2.6206e-05, test Loss: 2.3505e-05
# Epoch 21550, Train Loss: 2.7388e-05, test Loss: 2.4707e-05
# Epoch 21600, Train Loss: 2.6204e-05, test Loss: 2.3495e-05
# Epoch 21650, Train Loss: 2.6203e-05, test Loss: 2.3504e-05
# Epoch 21700, Train Loss: 2.6202e-05, test Loss: 2.3501e-05
# Epoch 21750, Train Loss: 2.6201e-05, test Loss: 2.3499e-05
# Epoch 21800, Train Loss: 2.7651e-05, test Loss: 2.4347e-05
# Epoch 21850, Train Loss: 2.6205e-05, test Loss: 2.3522e-05
# Epoch 21900, Train Loss: 2.6197e-05, test Loss: 2.3496e-05
# Epoch 21950, Train Loss: 2.6196e-05, test Loss: 2.3495e-05
# Epoch 22000, Train Loss: 2.6195e-05, test Loss: 2.3494e-05
# Epoch 22050, Train Loss: 2.6194e-05, test Loss: 2.3488e-05
# Epoch 22100, Train Loss: 2.6195e-05, test Loss: 2.3568e-05
# Epoch 22150, Train Loss: 2.6192e-05, test Loss: 2.3496e-05
# Epoch 22200, Train Loss: 2.6190e-05, test Loss: 2.3490e-05
# Epoch 22250, Train Loss: 2.6189e-05, test Loss: 2.3488e-05
# Epoch 22300, Train Loss: 2.6194e-05, test Loss: 2.3463e-05
# Epoch 22350, Train Loss: 2.6208e-05, test Loss: 2.3460e-05
# Epoch 22400, Train Loss: 2.6186e-05, test Loss: 2.3481e-05
# Epoch 22450, Train Loss: 2.6185e-05, test Loss: 2.3483e-05
# Epoch 22500, Train Loss: 2.6183e-05, test Loss: 2.3483e-05
# Epoch 22550, Train Loss: 2.7217e-05, test Loss: 2.3949e-05
# Epoch 22600, Train Loss: 2.6186e-05, test Loss: 2.3463e-05
# Epoch 22650, Train Loss: 2.6180e-05, test Loss: 2.3481e-05
# Epoch 22700, Train Loss: 2.6179e-05, test Loss: 2.3478e-05
# Epoch 22750, Train Loss: 2.6178e-05, test Loss: 2.3475e-05
# Epoch 22800, Train Loss: 2.6222e-05, test Loss: 2.3455e-05
# Epoch 22850, Train Loss: 2.6176e-05, test Loss: 2.3468e-05
# Epoch 22900, Train Loss: 2.6174e-05, test Loss: 2.3473e-05
# Epoch 22950, Train Loss: 2.6173e-05, test Loss: 2.3472e-05
# Epoch 23000, Train Loss: 2.6182e-05, test Loss: 2.3531e-05
# Epoch 23050, Train Loss: 2.6188e-05, test Loss: 2.3509e-05
# Epoch 23100, Train Loss: 2.6170e-05, test Loss: 2.3472e-05
# Epoch 23150, Train Loss: 2.6169e-05, test Loss: 2.3468e-05
# Epoch 23200, Train Loss: 2.6167e-05, test Loss: 2.3467e-05
# Epoch 23250, Train Loss: 2.7566e-05, test Loss: 2.5206e-05
# Epoch 23300, Train Loss: 2.6171e-05, test Loss: 2.3444e-05
# Epoch 23350, Train Loss: 2.6164e-05, test Loss: 2.3463e-05
# Epoch 23400, Train Loss: 2.6163e-05, test Loss: 2.3463e-05
# Epoch 23450, Train Loss: 2.6162e-05, test Loss: 2.3461e-05
# Epoch 23500, Train Loss: 2.6161e-05, test Loss: 2.3464e-05
# Epoch 23550, Train Loss: 2.6176e-05, test Loss: 2.3431e-05
# Epoch 23600, Train Loss: 2.6158e-05, test Loss: 2.3455e-05
# Epoch 23650, Train Loss: 2.6157e-05, test Loss: 2.3457e-05
# Epoch 23700, Train Loss: 2.6156e-05, test Loss: 2.3456e-05
# Epoch 23750, Train Loss: 2.6155e-05, test Loss: 2.3455e-05
# Epoch 23800, Train Loss: 2.6156e-05, test Loss: 2.3443e-05
# Epoch 23850, Train Loss: 2.6154e-05, test Loss: 2.3465e-05
# Epoch 23900, Train Loss: 2.6151e-05, test Loss: 2.3452e-05
# Epoch 23950, Train Loss: 2.6150e-05, test Loss: 2.3450e-05
# Epoch 24000, Train Loss: 2.6149e-05, test Loss: 2.3449e-05
# Epoch 24050, Train Loss: 2.6152e-05, test Loss: 2.3479e-05
# Epoch 24100, Train Loss: 2.6172e-05, test Loss: 2.3509e-05
# Epoch 24150, Train Loss: 2.6146e-05, test Loss: 2.3449e-05
# Epoch 24200, Train Loss: 2.6145e-05, test Loss: 2.3444e-05
# Epoch 24250, Train Loss: 2.6143e-05, test Loss: 2.3443e-05
# Epoch 24300, Train Loss: 2.6143e-05, test Loss: 2.3432e-05
# Epoch 24350, Train Loss: 2.6180e-05, test Loss: 2.3411e-05
# Epoch 24400, Train Loss: 2.6140e-05, test Loss: 2.3444e-05
# Epoch 24450, Train Loss: 2.6139e-05, test Loss: 2.3439e-05
# Epoch 24500, Train Loss: 2.6138e-05, test Loss: 2.3438e-05
# Epoch 24550, Train Loss: 2.6137e-05, test Loss: 2.3437e-05
# Epoch 24600, Train Loss: 2.6135e-05, test Loss: 2.3449e-05
# Epoch 24650, Train Loss: 2.6136e-05, test Loss: 2.3432e-05
# Epoch 24700, Train Loss: 2.6133e-05, test Loss: 2.3432e-05
# Epoch 24750, Train Loss: 2.6132e-05, test Loss: 2.3432e-05
# Epoch 24800, Train Loss: 2.6131e-05, test Loss: 2.3431e-05
# Epoch 24850, Train Loss: 2.6684e-05, test Loss: 2.4556e-05
# Epoch 24900, Train Loss: 2.6137e-05, test Loss: 2.3457e-05
# Epoch 24950, Train Loss: 2.6127e-05, test Loss: 2.3430e-05
# Epoch 25000, Train Loss: 2.6126e-05, test Loss: 2.3426e-05
# Epoch 25050, Train Loss: 2.6125e-05, test Loss: 2.3425e-05
# Epoch 25100, Train Loss: 2.6128e-05, test Loss: 2.3460e-05
# Epoch 25150, Train Loss: 2.6123e-05, test Loss: 2.3398e-05
# Epoch 25200, Train Loss: 2.6122e-05, test Loss: 2.3420e-05
# Epoch 25250, Train Loss: 2.6121e-05, test Loss: 2.3421e-05
# Epoch 25300, Train Loss: 2.6119e-05, test Loss: 2.3420e-05
# Epoch 25350, Train Loss: 2.6118e-05, test Loss: 2.3418e-05
# Epoch 25400, Train Loss: 2.6224e-05, test Loss: 2.3690e-05
# Epoch 25450, Train Loss: 2.6116e-05, test Loss: 2.3420e-05
# Epoch 25500, Train Loss: 2.6115e-05, test Loss: 2.3414e-05
# Epoch 25550, Train Loss: 2.6114e-05, test Loss: 2.3414e-05
# Epoch 25600, Train Loss: 2.6113e-05, test Loss: 2.3410e-05
# Epoch 25650, Train Loss: 2.6183e-05, test Loss: 2.3387e-05
# Epoch 25700, Train Loss: 2.6111e-05, test Loss: 2.3405e-05
# Epoch 25750, Train Loss: 2.6109e-05, test Loss: 2.3410e-05
# Epoch 25800, Train Loss: 2.6108e-05, test Loss: 2.3408e-05
# Epoch 25850, Train Loss: 2.6109e-05, test Loss: 2.3432e-05
# Epoch 25900, Train Loss: 2.6133e-05, test Loss: 2.3477e-05
# Epoch 25950, Train Loss: 2.6105e-05, test Loss: 2.3407e-05
# Epoch 26000, Train Loss: 2.6103e-05, test Loss: 2.3403e-05
# Epoch 26050, Train Loss: 2.6102e-05, test Loss: 2.3403e-05
# Epoch 26100, Train Loss: 2.6101e-05, test Loss: 2.3405e-05
# Epoch 26150, Train Loss: 2.6157e-05, test Loss: 2.3374e-05
# Epoch 26200, Train Loss: 2.6099e-05, test Loss: 2.3406e-05
# Epoch 26250, Train Loss: 2.6098e-05, test Loss: 2.3398e-05
# Epoch 26300, Train Loss: 2.6096e-05, test Loss: 2.3397e-05
# Epoch 26350, Train Loss: 2.6095e-05, test Loss: 2.3396e-05
# Epoch 26400, Train Loss: 2.6582e-05, test Loss: 2.3801e-05
# Epoch 26450, Train Loss: 2.6096e-05, test Loss: 2.3379e-05
# Epoch 26500, Train Loss: 2.6092e-05, test Loss: 2.3392e-05
# Epoch 26550, Train Loss: 2.6091e-05, test Loss: 2.3391e-05
# Epoch 26600, Train Loss: 2.6090e-05, test Loss: 2.3390e-05
# Epoch 26650, Train Loss: 2.6120e-05, test Loss: 2.3766e-05
# Epoch 26700, Train Loss: 2.6088e-05, test Loss: 2.3406e-05
# Epoch 26750, Train Loss: 2.6086e-05, test Loss: 2.3386e-05
# Epoch 26800, Train Loss: 2.6085e-05, test Loss: 2.3385e-05
# Epoch 26850, Train Loss: 2.6084e-05, test Loss: 2.3384e-05
# Epoch 26900, Train Loss: 2.6085e-05, test Loss: 2.3353e-05
# Epoch 26950, Train Loss: 2.6082e-05, test Loss: 2.3392e-05
# Epoch 27000, Train Loss: 2.6080e-05, test Loss: 2.3382e-05
# Epoch 27050, Train Loss: 2.6079e-05, test Loss: 2.3380e-05
# Epoch 27100, Train Loss: 2.6078e-05, test Loss: 2.3379e-05
# Epoch 27150, Train Loss: 2.6338e-05, test Loss: 2.3560e-05
# Epoch 27200, Train Loss: 2.6079e-05, test Loss: 2.3382e-05
# Epoch 27250, Train Loss: 2.6075e-05, test Loss: 2.3377e-05
# Epoch 27300, Train Loss: 2.6073e-05, test Loss: 2.3374e-05
# Epoch 27350, Train Loss: 2.6072e-05, test Loss: 2.3374e-05
# Epoch 27400, Train Loss: 2.6272e-05, test Loss: 2.3765e-05
# Epoch 27450, Train Loss: 2.6071e-05, test Loss: 2.3382e-05
# Epoch 27500, Train Loss: 2.6069e-05, test Loss: 2.3369e-05
# Epoch 27550, Train Loss: 2.6068e-05, test Loss: 2.3369e-05
# Epoch 27600, Train Loss: 2.6067e-05, test Loss: 2.3378e-05
# Epoch 27650, Train Loss: 2.6103e-05, test Loss: 2.3336e-05
# Epoch 27700, Train Loss: 2.6064e-05, test Loss: 2.3360e-05
# Epoch 27750, Train Loss: 2.6063e-05, test Loss: 2.3364e-05
# Epoch 27800, Train Loss: 2.6062e-05, test Loss: 2.3363e-05
# Epoch 27850, Train Loss: 2.6086e-05, test Loss: 2.3333e-05
# Epoch 27900, Train Loss: 2.6064e-05, test Loss: 2.3358e-05
# Epoch 27950, Train Loss: 2.6059e-05, test Loss: 2.3357e-05
# Epoch 28000, Train Loss: 2.6057e-05, test Loss: 2.3359e-05
# Epoch 28050, Train Loss: 2.6056e-05, test Loss: 2.3357e-05
# Epoch 28100, Train Loss: 2.6055e-05, test Loss: 2.3358e-05
# Epoch 28150, Train Loss: 2.6159e-05, test Loss: 2.3350e-05
# Epoch 28200, Train Loss: 2.6053e-05, test Loss: 2.3346e-05
# Epoch 28250, Train Loss: 2.6052e-05, test Loss: 2.3352e-05
# Epoch 28300, Train Loss: 2.6050e-05, test Loss: 2.3352e-05
# Epoch 28350, Train Loss: 2.6359e-05, test Loss: 2.3581e-05
# Epoch 28400, Train Loss: 2.6053e-05, test Loss: 2.3361e-05
# Epoch 28450, Train Loss: 2.6047e-05, test Loss: 2.3348e-05
# Epoch 28500, Train Loss: 2.6046e-05, test Loss: 2.3347e-05
# Epoch 28550, Train Loss: 2.6045e-05, test Loss: 2.3347e-05
# Epoch 28600, Train Loss: 2.6158e-05, test Loss: 2.3334e-05
# Epoch 28650, Train Loss: 2.6043e-05, test Loss: 2.3335e-05
# Epoch 28700, Train Loss: 2.6041e-05, test Loss: 2.3342e-05
# Epoch 28750, Train Loss: 2.6040e-05, test Loss: 2.3341e-05
# Epoch 28800, Train Loss: 2.6347e-05, test Loss: 2.3567e-05
# Epoch 28850, Train Loss: 2.6044e-05, test Loss: 2.3359e-05
# Epoch 28900, Train Loss: 2.6037e-05, test Loss: 2.3337e-05
# Epoch 28950, Train Loss: 2.6035e-05, test Loss: 2.3337e-05
# Epoch 29000, Train Loss: 2.6034e-05, test Loss: 2.3335e-05
# Epoch 29050, Train Loss: 2.6100e-05, test Loss: 2.3624e-05
# Epoch 29100, Train Loss: 2.6032e-05, test Loss: 2.3325e-05
# Epoch 29150, Train Loss: 2.6031e-05, test Loss: 2.3333e-05
# Epoch 29200, Train Loss: 2.6030e-05, test Loss: 2.3331e-05
# Epoch 29250, Train Loss: 2.6028e-05, test Loss: 2.3330e-05
# Epoch 29300, Train Loss: 2.6453e-05, test Loss: 2.4039e-05
# Epoch 29350, Train Loss: 2.6027e-05, test Loss: 2.3329e-05
# Epoch 29400, Train Loss: 2.6025e-05, test Loss: 2.3327e-05
# Epoch 29450, Train Loss: 2.6024e-05, test Loss: 2.3325e-05
# Epoch 29500, Train Loss: 2.6023e-05, test Loss: 2.3325e-05
# Epoch 29550, Train Loss: 2.6221e-05, test Loss: 2.3466e-05
# Epoch 29600, Train Loss: 2.6022e-05, test Loss: 2.3311e-05
# Epoch 29650, Train Loss: 2.6019e-05, test Loss: 2.3321e-05
# Epoch 29700, Train Loss: 2.6018e-05, test Loss: 2.3320e-05
# Epoch 29750, Train Loss: 2.6017e-05, test Loss: 2.3318e-05
# Epoch 29800, Train Loss: 2.6487e-05, test Loss: 2.3679e-05
# Epoch 29850, Train Loss: 2.6017e-05, test Loss: 2.3304e-05
# Epoch 29900, Train Loss: 2.6013e-05, test Loss: 2.3314e-05
# Epoch 29950, Train Loss: 2.6012e-05, test Loss: 2.3314e-05
# Epoch 30000, Train Loss: 2.6011e-05, test Loss: 2.3313e-05
# Epoch 30050, Train Loss: 2.6984e-05, test Loss: 2.4818e-05
# Epoch 30100, Train Loss: 2.6015e-05, test Loss: 2.3335e-05
# Epoch 30150, Train Loss: 2.6008e-05, test Loss: 2.3311e-05
# Epoch 30200, Train Loss: 2.6007e-05, test Loss: 2.3308e-05
# Epoch 30250, Train Loss: 2.6005e-05, test Loss: 2.3307e-05
# Epoch 30300, Train Loss: 2.6136e-05, test Loss: 2.3491e-05
# Epoch 30350, Train Loss: 2.6003e-05, test Loss: 2.3313e-05
# Epoch 30400, Train Loss: 2.6002e-05, test Loss: 2.3303e-05
# Epoch 30450, Train Loss: 2.6001e-05, test Loss: 2.3303e-05
# Epoch 30500, Train Loss: 2.6000e-05, test Loss: 2.3302e-05
# Epoch 30550, Train Loss: 2.6391e-05, test Loss: 2.3643e-05
# Epoch 30600, Train Loss: 2.6005e-05, test Loss: 2.3284e-05
# Epoch 30650, Train Loss: 2.5996e-05, test Loss: 2.3299e-05
# Epoch 30700, Train Loss: 2.5995e-05, test Loss: 2.3297e-05
# Epoch 30750, Train Loss: 2.5994e-05, test Loss: 2.3296e-05
# Epoch 30800, Train Loss: 2.5993e-05, test Loss: 2.3291e-05
# Epoch 30850, Train Loss: 2.6003e-05, test Loss: 2.3406e-05
# Epoch 30900, Train Loss: 2.5991e-05, test Loss: 2.3293e-05
# Epoch 30950, Train Loss: 2.5989e-05, test Loss: 2.3292e-05
# Epoch 31000, Train Loss: 2.5988e-05, test Loss: 2.3290e-05
# Epoch 31050, Train Loss: 2.5987e-05, test Loss: 2.3290e-05
# Epoch 31100, Train Loss: 2.6106e-05, test Loss: 2.3279e-05
# Epoch 31150, Train Loss: 2.5985e-05, test Loss: 2.3279e-05
# Epoch 31200, Train Loss: 2.5984e-05, test Loss: 2.3286e-05
# Epoch 31250, Train Loss: 2.5982e-05, test Loss: 2.3285e-05
# Epoch 31300, Train Loss: 2.5983e-05, test Loss: 2.3307e-05
# Epoch 31350, Train Loss: 2.6008e-05, test Loss: 2.3343e-05
# Epoch 31400, Train Loss: 2.5979e-05, test Loss: 2.3280e-05
# Epoch 31450, Train Loss: 2.5978e-05, test Loss: 2.3280e-05
# Epoch 31500, Train Loss: 2.5977e-05, test Loss: 2.3279e-05
# Epoch 31550, Train Loss: 2.5976e-05, test Loss: 2.3274e-05
# Epoch 31600, Train Loss: 2.5975e-05, test Loss: 2.3323e-05
# Epoch 31650, Train Loss: 2.5974e-05, test Loss: 2.3282e-05
# Epoch 31700, Train Loss: 2.5972e-05, test Loss: 2.3274e-05
# Epoch 31750, Train Loss: 2.5971e-05, test Loss: 2.3273e-05
# Epoch 31800, Train Loss: 2.5970e-05, test Loss: 2.3272e-05
# Epoch 31850, Train Loss: 2.6120e-05, test Loss: 2.3369e-05
# Epoch 31900, Train Loss: 2.5968e-05, test Loss: 2.3282e-05
# Epoch 31950, Train Loss: 2.5966e-05, test Loss: 2.3269e-05
# Epoch 32000, Train Loss: 2.5965e-05, test Loss: 2.3268e-05
# Epoch 32050, Train Loss: 2.5964e-05, test Loss: 2.3266e-05
# Epoch 32100, Train Loss: 2.5963e-05, test Loss: 2.3270e-05
# Epoch 32150, Train Loss: 2.5992e-05, test Loss: 2.3237e-05
# Epoch 32200, Train Loss: 2.5961e-05, test Loss: 2.3260e-05
# Epoch 32250, Train Loss: 2.5959e-05, test Loss: 2.3262e-05
# Epoch 32300, Train Loss: 2.5958e-05, test Loss: 2.3261e-05
# Epoch 32350, Train Loss: 2.5957e-05, test Loss: 2.3259e-05
# Epoch 32400, Train Loss: 2.5978e-05, test Loss: 2.3242e-05
# Epoch 32450, Train Loss: 2.5955e-05, test Loss: 2.3265e-05
# Epoch 32500, Train Loss: 2.5954e-05, test Loss: 2.3256e-05
# Epoch 32550, Train Loss: 2.5953e-05, test Loss: 2.3255e-05
# Epoch 32600, Train Loss: 2.5951e-05, test Loss: 2.3254e-05
# Epoch 32650, Train Loss: 2.7139e-05, test Loss: 2.5026e-05
# Epoch 32700, Train Loss: 2.5954e-05, test Loss: 2.3230e-05
# Epoch 32750, Train Loss: 2.5948e-05, test Loss: 2.3250e-05
# Epoch 32800, Train Loss: 2.5947e-05, test Loss: 2.3250e-05
# Epoch 32850, Train Loss: 2.5946e-05, test Loss: 2.3248e-05
# Epoch 32900, Train Loss: 2.5945e-05, test Loss: 2.3246e-05
# Epoch 32950, Train Loss: 2.6015e-05, test Loss: 2.3217e-05
# Epoch 33000, Train Loss: 2.5943e-05, test Loss: 2.3252e-05
# Epoch 33050, Train Loss: 2.5941e-05, test Loss: 2.3244e-05
# Epoch 33100, Train Loss: 2.5940e-05, test Loss: 2.3243e-05
# Epoch 33150, Train Loss: 2.5939e-05, test Loss: 2.3242e-05
# Epoch 33200, Train Loss: 2.5938e-05, test Loss: 2.3266e-05
# Epoch 33250, Train Loss: 2.5940e-05, test Loss: 2.3266e-05
# Epoch 33300, Train Loss: 2.5935e-05, test Loss: 2.3239e-05
# Epoch 33350, Train Loss: 2.5934e-05, test Loss: 2.3237e-05
# Epoch 33400, Train Loss: 2.5933e-05, test Loss: 2.3236e-05
# Epoch 33450, Train Loss: 2.5932e-05, test Loss: 2.3239e-05
# Epoch 33500, Train Loss: 2.5931e-05, test Loss: 2.3206e-05
# Epoch 33550, Train Loss: 2.5930e-05, test Loss: 2.3227e-05
# Epoch 33600, Train Loss: 2.5929e-05, test Loss: 2.3232e-05
# Epoch 33650, Train Loss: 2.5927e-05, test Loss: 2.3230e-05
# Epoch 33700, Train Loss: 2.5926e-05, test Loss: 2.3227e-05
# Epoch 33750, Train Loss: 2.5963e-05, test Loss: 2.3217e-05
# Epoch 33800, Train Loss: 2.5924e-05, test Loss: 2.3230e-05
# Epoch 33850, Train Loss: 2.5923e-05, test Loss: 2.3226e-05
# Epoch 33900, Train Loss: 2.5922e-05, test Loss: 2.3225e-05
# Epoch 33950, Train Loss: 2.5920e-05, test Loss: 2.3224e-05
# Epoch 34000, Train Loss: 2.6119e-05, test Loss: 2.3193e-05
# Epoch 34050, Train Loss: 2.5918e-05, test Loss: 2.3225e-05
# Epoch 34100, Train Loss: 2.5917e-05, test Loss: 2.3221e-05
# Epoch 34150, Train Loss: 2.5916e-05, test Loss: 2.3219e-05
# Epoch 34200, Train Loss: 2.5915e-05, test Loss: 2.3216e-05
# Epoch 34250, Train Loss: 2.6009e-05, test Loss: 2.3192e-05
# Epoch 34300, Train Loss: 2.5913e-05, test Loss: 2.3224e-05
# Epoch 34350, Train Loss: 2.5911e-05, test Loss: 2.3215e-05
# Epoch 34400, Train Loss: 2.5910e-05, test Loss: 2.3213e-05
# Epoch 34450, Train Loss: 2.5909e-05, test Loss: 2.3212e-05
# Epoch 34500, Train Loss: 2.6018e-05, test Loss: 2.3221e-05
# Epoch 34550, Train Loss: 2.5908e-05, test Loss: 2.3197e-05
# Epoch 34600, Train Loss: 2.5906e-05, test Loss: 2.3210e-05
# Epoch 34650, Train Loss: 2.5904e-05, test Loss: 2.3208e-05
# Epoch 34700, Train Loss: 2.5903e-05, test Loss: 2.3208e-05
# Epoch 34750, Train Loss: 2.6016e-05, test Loss: 2.3192e-05
# Epoch 34800, Train Loss: 2.5902e-05, test Loss: 2.3196e-05
# Epoch 34850, Train Loss: 2.5900e-05, test Loss: 2.3203e-05
# Epoch 34900, Train Loss: 2.5899e-05, test Loss: 2.3202e-05
# Epoch 34950, Train Loss: 2.5898e-05, test Loss: 2.3216e-05
# Epoch 35000, Train Loss: 2.5914e-05, test Loss: 2.3213e-05
# Epoch 35050, Train Loss: 2.5895e-05, test Loss: 2.3198e-05
# Epoch 35100, Train Loss: 2.5894e-05, test Loss: 2.3197e-05
# Epoch 35150, Train Loss: 2.5893e-05, test Loss: 2.3196e-05
# Epoch 35200, Train Loss: 2.5892e-05, test Loss: 2.3195e-05
# Epoch 35250, Train Loss: 2.5960e-05, test Loss: 2.3255e-05
# Epoch 35300, Train Loss: 2.5893e-05, test Loss: 2.3217e-05
# Epoch 35350, Train Loss: 2.5888e-05, test Loss: 2.3192e-05
# Epoch 35400, Train Loss: 2.5887e-05, test Loss: 2.3191e-05
# Epoch 35450, Train Loss: 2.5886e-05, test Loss: 2.3190e-05
# Epoch 35500, Train Loss: 2.6288e-05, test Loss: 2.4146e-05
# Epoch 35550, Train Loss: 2.5892e-05, test Loss: 2.3177e-05
# Epoch 35600, Train Loss: 2.5883e-05, test Loss: 2.3184e-05
# Epoch 35650, Train Loss: 2.5882e-05, test Loss: 2.3185e-05
# Epoch 35700, Train Loss: 2.5880e-05, test Loss: 2.3184e-05
# Epoch 35750, Train Loss: 2.5879e-05, test Loss: 2.3183e-05
# Epoch 35800, Train Loss: 2.5878e-05, test Loss: 2.3179e-05
# Epoch 35850, Train Loss: 2.5890e-05, test Loss: 2.3194e-05
# Epoch 35900, Train Loss: 2.5876e-05, test Loss: 2.3186e-05
# Epoch 35950, Train Loss: 2.5875e-05, test Loss: 2.3178e-05
# Epoch 36000, Train Loss: 2.5873e-05, test Loss: 2.3177e-05
# Epoch 36050, Train Loss: 2.5872e-05, test Loss: 2.3177e-05
# Epoch 36100, Train Loss: 2.6000e-05, test Loss: 2.3167e-05
# Epoch 36150, Train Loss: 2.5871e-05, test Loss: 2.3170e-05
# Epoch 36200, Train Loss: 2.5869e-05, test Loss: 2.3174e-05
# Epoch 36250, Train Loss: 2.5868e-05, test Loss: 2.3172e-05
# Epoch 36300, Train Loss: 2.5867e-05, test Loss: 2.3167e-05
# Epoch 36350, Train Loss: 2.5871e-05, test Loss: 2.3265e-05
# Epoch 36400, Train Loss: 2.5865e-05, test Loss: 2.3170e-05
# Epoch 36450, Train Loss: 2.5863e-05, test Loss: 2.3167e-05
# Epoch 36500, Train Loss: 2.5862e-05, test Loss: 2.3166e-05
# Epoch 36550, Train Loss: 2.5861e-05, test Loss: 2.3164e-05
# Epoch 36600, Train Loss: 2.5965e-05, test Loss: 2.3433e-05
# Epoch 36650, Train Loss: 2.5859e-05, test Loss: 2.3163e-05
# Epoch 36700, Train Loss: 2.5857e-05, test Loss: 2.3161e-05
# Epoch 36750, Train Loss: 2.5856e-05, test Loss: 2.3160e-05
# Epoch 36800, Train Loss: 2.5855e-05, test Loss: 2.3159e-05
# Epoch 36850, Train Loss: 2.6121e-05, test Loss: 2.3337e-05
# Epoch 36900, Train Loss: 2.5854e-05, test Loss: 2.3144e-05
# Epoch 36950, Train Loss: 2.5852e-05, test Loss: 2.3157e-05
# Epoch 37000, Train Loss: 2.5851e-05, test Loss: 2.3155e-05
# Epoch 37050, Train Loss: 2.5849e-05, test Loss: 2.3154e-05
# Epoch 37100, Train Loss: 2.5848e-05, test Loss: 2.3153e-05
# Epoch 37150, Train Loss: 2.6052e-05, test Loss: 2.3572e-05
# Epoch 37200, Train Loss: 2.5846e-05, test Loss: 2.3149e-05
# Epoch 37250, Train Loss: 2.5845e-05, test Loss: 2.3150e-05
# Epoch 37300, Train Loss: 2.5844e-05, test Loss: 2.3148e-05
# Epoch 37350, Train Loss: 2.5843e-05, test Loss: 2.3147e-05
# Epoch 37400, Train Loss: 2.5908e-05, test Loss: 2.3147e-05
# Epoch 37450, Train Loss: 2.5841e-05, test Loss: 2.3149e-05
# Epoch 37500, Train Loss: 2.5839e-05, test Loss: 2.3144e-05
# Epoch 37550, Train Loss: 2.5838e-05, test Loss: 2.3142e-05
# Epoch 37600, Train Loss: 2.5837e-05, test Loss: 2.3141e-05
# Epoch 37650, Train Loss: 2.5848e-05, test Loss: 2.3212e-05
# Epoch 37700, Train Loss: 2.5856e-05, test Loss: 2.3172e-05
# Epoch 37750, Train Loss: 2.5834e-05, test Loss: 2.3139e-05
# Epoch 37800, Train Loss: 2.5832e-05, test Loss: 2.3137e-05
# Epoch 37850, Train Loss: 2.5831e-05, test Loss: 2.3136e-05
# Epoch 37900, Train Loss: 2.5830e-05, test Loss: 2.3135e-05
# Epoch 37950, Train Loss: 2.5829e-05, test Loss: 2.3134e-05
# Epoch 38000, Train Loss: 2.5948e-05, test Loss: 2.3217e-05
# Epoch 38050, Train Loss: 2.5827e-05, test Loss: 2.3137e-05
# Epoch 38100, Train Loss: 2.5826e-05, test Loss: 2.3129e-05
# Epoch 38150, Train Loss: 2.5824e-05, test Loss: 2.3129e-05
# Epoch 38200, Train Loss: 2.5868e-05, test Loss: 2.3290e-05
# Epoch 38250, Train Loss: 2.5822e-05, test Loss: 2.3112e-05
# Epoch 38300, Train Loss: 2.5821e-05, test Loss: 2.3128e-05
# Epoch 38350, Train Loss: 2.5820e-05, test Loss: 2.3124e-05
# Epoch 38400, Train Loss: 2.5819e-05, test Loss: 2.3123e-05
# Epoch 38450, Train Loss: 2.6073e-05, test Loss: 2.3132e-05
# Epoch 38500, Train Loss: 2.5817e-05, test Loss: 2.3135e-05
# Epoch 38550, Train Loss: 2.5815e-05, test Loss: 2.3119e-05
# Epoch 38600, Train Loss: 2.5814e-05, test Loss: 2.3119e-05
# Epoch 38650, Train Loss: 2.5813e-05, test Loss: 2.3117e-05
# Epoch 38700, Train Loss: 2.5812e-05, test Loss: 2.3097e-05
# Epoch 38750, Train Loss: 2.5813e-05, test Loss: 2.3104e-05
# Epoch 38800, Train Loss: 2.5809e-05, test Loss: 2.3115e-05
# Epoch 38850, Train Loss: 2.5808e-05, test Loss: 2.3113e-05
# Epoch 38900, Train Loss: 2.5807e-05, test Loss: 2.3112e-05
# Epoch 38950, Train Loss: 2.5825e-05, test Loss: 2.3083e-05
# Epoch 39000, Train Loss: 2.5805e-05, test Loss: 2.3111e-05
# Epoch 39050, Train Loss: 2.5804e-05, test Loss: 2.3108e-05
# Epoch 39100, Train Loss: 2.5803e-05, test Loss: 2.3107e-05
# Epoch 39150, Train Loss: 2.5801e-05, test Loss: 2.3106e-05
# Epoch 39200, Train Loss: 2.6609e-05, test Loss: 2.3867e-05
# Epoch 39250, Train Loss: 2.5801e-05, test Loss: 2.3137e-05
# Epoch 39300, Train Loss: 2.5798e-05, test Loss: 2.3104e-05
# Epoch 39350, Train Loss: 2.5797e-05, test Loss: 2.3102e-05
# Epoch 39400, Train Loss: 2.5796e-05, test Loss: 2.3101e-05
# Epoch 39450, Train Loss: 2.5795e-05, test Loss: 2.3099e-05
# Epoch 39500, Train Loss: 2.5917e-05, test Loss: 2.3207e-05
# Epoch 39550, Train Loss: 2.5793e-05, test Loss: 2.3089e-05
# Epoch 39600, Train Loss: 2.5791e-05, test Loss: 2.3096e-05
# Epoch 39650, Train Loss: 2.5790e-05, test Loss: 2.3095e-05
# Epoch 39700, Train Loss: 2.5789e-05, test Loss: 2.3094e-05
# Epoch 39750, Train Loss: 2.5815e-05, test Loss: 2.3105e-05
# Epoch 39800, Train Loss: 2.5788e-05, test Loss: 2.3080e-05
# Epoch 39850, Train Loss: 2.5785e-05, test Loss: 2.3091e-05
# Epoch 39900, Train Loss: 2.5784e-05, test Loss: 2.3089e-05
# Epoch 39950, Train Loss: 2.5784e-05, test Loss: 2.3098e-05
# Epoch 40000, Train Loss: 2.5798e-05, test Loss: 2.3058e-05
# Epoch 40050, Train Loss: 2.5781e-05, test Loss: 2.3087e-05
# Epoch 40100, Train Loss: 2.5780e-05, test Loss: 2.3085e-05
# Epoch 40150, Train Loss: 2.5779e-05, test Loss: 2.3084e-05
# Epoch 40200, Train Loss: 2.6191e-05, test Loss: 2.3060e-05
# Epoch 40250, Train Loss: 2.5781e-05, test Loss: 2.3105e-05
# Epoch 40300, Train Loss: 2.5775e-05, test Loss: 2.3082e-05
# Epoch 40350, Train Loss: 2.5774e-05, test Loss: 2.3079e-05
# Epoch 40400, Train Loss: 2.5773e-05, test Loss: 2.3078e-05
# Epoch 40450, Train Loss: 2.5949e-05, test Loss: 2.3557e-05
# Epoch 40500, Train Loss: 2.5781e-05, test Loss: 2.3099e-05
# Epoch 40550, Train Loss: 2.5770e-05, test Loss: 2.3072e-05
# Epoch 40600, Train Loss: 2.5768e-05, test Loss: 2.3074e-05
# Epoch 40650, Train Loss: 2.5767e-05, test Loss: 2.3073e-05
# Epoch 40700, Train Loss: 2.5766e-05, test Loss: 2.3072e-05
# Epoch 40750, Train Loss: 2.5910e-05, test Loss: 2.3561e-05
# Epoch 40800, Train Loss: 2.5766e-05, test Loss: 2.3058e-05
# ...
# Epoch 165350, Train Loss: 2.0768e-05, test Loss: 1.7949e-05
# Epoch 165400, Train Loss: 2.0768e-05, test Loss: 1.7954e-05
# Epoch 165450, Train Loss: 2.0813e-05, test Loss: 1.8047e-05
# Epoch 165500, Train Loss: 2.0768e-05, test Loss: 1.7946e-05
# Epoch 165550, Train Loss: 2.0768e-05, test Loss: 1.7948e-05
# Epoch 165600, Train Loss: 2.0768e-05, test Loss: 1.7950e-05
# Epoch 165650, Train Loss: 2.0798e-05, test Loss: 1.7923e-05
# Epoch 165700, Train Loss: 2.0768e-05, test Loss: 1.7948e-05
# Epoch 165750, Train Loss: 2.0768e-05, test Loss: 1.7948e-05
# Epoch 165800, Train Loss: 2.0768e-05, test Loss: 1.7948e-05
# Epoch 165850, Train Loss: 2.0921e-05, test Loss: 1.7928e-05
# Epoch 165900, Train Loss: 2.0769e-05, test Loss: 1.7942e-05
# Epoch 165950, Train Loss: 2.0768e-05, test Loss: 1.7949e-05
# Epoch 166000, Train Loss: 2.0768e-05, test Loss: 1.7948e-05
# Epoch 166050, Train Loss: 2.0772e-05, test Loss: 1.7983e-05
# Epoch 166100, Train Loss: 2.0769e-05, test Loss: 1.7989e-05
# Epoch 166150, Train Loss: 2.0768e-05, test Loss: 1.7944e-05
# Epoch 166200, Train Loss: 2.0767e-05, test Loss: 1.7948e-05
# Epoch 166250, Train Loss: 2.0767e-05, test Loss: 1.7947e-05
# Epoch 166300, Train Loss: 2.0803e-05, test Loss: 1.7955e-05
# Epoch 166350, Train Loss: 2.0767e-05, test Loss: 1.7953e-05
# Epoch 166400, Train Loss: 2.0767e-05, test Loss: 1.7948e-05
# Epoch 166450, Train Loss: 2.0767e-05, test Loss: 1.7948e-05
# Epoch 166500, Train Loss: 2.0771e-05, test Loss: 1.7980e-05
# Epoch 166550, Train Loss: 2.0775e-05, test Loss: 1.8009e-05
# Epoch 166600, Train Loss: 2.0767e-05, test Loss: 1.7946e-05
# Epoch 166650, Train Loss: 2.0767e-05, test Loss: 1.7947e-05
# Epoch 166700, Train Loss: 2.0767e-05, test Loss: 1.7947e-05
# Epoch 166750, Train Loss: 2.1263e-05, test Loss: 1.9052e-05
# Epoch 166800, Train Loss: 2.0775e-05, test Loss: 1.7922e-05
# Epoch 166850, Train Loss: 2.0767e-05, test Loss: 1.7949e-05
# Epoch 166900, Train Loss: 2.0767e-05, test Loss: 1.7947e-05
# Epoch 166950, Train Loss: 2.0767e-05, test Loss: 1.7947e-05
# Epoch 167000, Train Loss: 2.0767e-05, test Loss: 1.7948e-05
# Epoch 167050, Train Loss: 2.0974e-05, test Loss: 1.7919e-05
# Epoch 167100, Train Loss: 2.0767e-05, test Loss: 1.7934e-05
# Epoch 167150, Train Loss: 2.0767e-05, test Loss: 1.7946e-05
# Epoch 167200, Train Loss: 2.0767e-05, test Loss: 1.7947e-05
# Epoch 167250, Train Loss: 2.0808e-05, test Loss: 1.7915e-05
# Epoch 167300, Train Loss: 2.0767e-05, test Loss: 1.7947e-05
# Epoch 167350, Train Loss: 2.0767e-05, test Loss: 1.7945e-05
# Epoch 167400, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 167450, Train Loss: 2.0769e-05, test Loss: 1.7926e-05
# Epoch 167500, Train Loss: 2.0768e-05, test Loss: 1.7920e-05
# Epoch 167550, Train Loss: 2.0766e-05, test Loss: 1.7949e-05
# Epoch 167600, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 167650, Train Loss: 2.0766e-05, test Loss: 1.7947e-05
# Epoch 167700, Train Loss: 2.0804e-05, test Loss: 1.7982e-05
# Epoch 167750, Train Loss: 2.0766e-05, test Loss: 1.7957e-05
# Epoch 167800, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 167850, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 167900, Train Loss: 2.0766e-05, test Loss: 1.7939e-05
# Epoch 167950, Train Loss: 2.0789e-05, test Loss: 1.8052e-05
# Epoch 168000, Train Loss: 2.0766e-05, test Loss: 1.7951e-05
# Epoch 168050, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 168100, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 168150, Train Loss: 2.0894e-05, test Loss: 1.8313e-05
# Epoch 168200, Train Loss: 2.0775e-05, test Loss: 1.7922e-05
# Epoch 168250, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 168300, Train Loss: 2.0766e-05, test Loss: 1.7945e-05
# Epoch 168350, Train Loss: 2.0766e-05, test Loss: 1.7947e-05
# Epoch 168400, Train Loss: 2.0825e-05, test Loss: 1.7925e-05
# Epoch 168450, Train Loss: 2.0766e-05, test Loss: 1.7944e-05
# Epoch 168500, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 168550, Train Loss: 2.0766e-05, test Loss: 1.7946e-05
# Epoch 168600, Train Loss: 2.1076e-05, test Loss: 1.8071e-05
# Epoch 168650, Train Loss: 2.0766e-05, test Loss: 1.7935e-05
# Epoch 168700, Train Loss: 2.0765e-05, test Loss: 1.7944e-05
# Epoch 168750, Train Loss: 2.0765e-05, test Loss: 1.7945e-05
# Epoch 168800, Train Loss: 2.0887e-05, test Loss: 1.7976e-05
# Epoch 168850, Train Loss: 2.0774e-05, test Loss: 1.7972e-05
# Epoch 168900, Train Loss: 2.0765e-05, test Loss: 1.7946e-05
# Epoch 168950, Train Loss: 2.0765e-05, test Loss: 1.7944e-05
# Epoch 169000, Train Loss: 2.0765e-05, test Loss: 1.7944e-05
# Epoch 169050, Train Loss: 2.0933e-05, test Loss: 1.7934e-05
# Epoch 169100, Train Loss: 2.0765e-05, test Loss: 1.7936e-05
# Epoch 169150, Train Loss: 2.0765e-05, test Loss: 1.7944e-05
# Epoch 169200, Train Loss: 2.0765e-05, test Loss: 1.7945e-05
# Epoch 169250, Train Loss: 2.1793e-05, test Loss: 1.9430e-05
# Epoch 169300, Train Loss: 2.0766e-05, test Loss: 1.7941e-05
# Epoch 169350, Train Loss: 2.0765e-05, test Loss: 1.7946e-05
# Epoch 169400, Train Loss: 2.0765e-05, test Loss: 1.7944e-05
# Epoch 169450, Train Loss: 2.0765e-05, test Loss: 1.7944e-05
# Epoch 169500, Train Loss: 2.1664e-05, test Loss: 1.9405e-05
# Epoch 169550, Train Loss: 2.0768e-05, test Loss: 1.7950e-05
# Epoch 169600, Train Loss: 2.0765e-05, test Loss: 1.7946e-05
# Epoch 169650, Train Loss: 2.0765e-05, test Loss: 1.7944e-05
# Epoch 169700, Train Loss: 2.0765e-05, test Loss: 1.7944e-05
# Epoch 169750, Train Loss: 2.1720e-05, test Loss: 1.8950e-05
# Epoch 169800, Train Loss: 2.0767e-05, test Loss: 1.7951e-05
# Epoch 169850, Train Loss: 2.0765e-05, test Loss: 1.7945e-05
# Epoch 169900, Train Loss: 2.0765e-05, test Loss: 1.7943e-05
# Epoch 169950, Train Loss: 2.0764e-05, test Loss: 1.7943e-05
# Epoch 170000, Train Loss: 2.0799e-05, test Loss: 1.8146e-05
# Epoch 170050, Train Loss: 2.0765e-05, test Loss: 1.7953e-05
# Epoch 170100, Train Loss: 2.0764e-05, test Loss: 1.7944e-05
# Epoch 170150, Train Loss: 2.0764e-05, test Loss: 1.7944e-05
# Epoch 170200, Train Loss: 2.0765e-05, test Loss: 1.7955e-05
# Epoch 170250, Train Loss: 2.0790e-05, test Loss: 1.8041e-05
# Epoch 170300, Train Loss: 2.0764e-05, test Loss: 1.7939e-05
# Epoch 170350, Train Loss: 2.0764e-05, test Loss: 1.7944e-05
# Epoch 170400, Train Loss: 2.0764e-05, test Loss: 1.7943e-05
# Epoch 170450, Train Loss: 2.0764e-05, test Loss: 1.7943e-05
# Epoch 170500, Train Loss: 2.0938e-05, test Loss: 1.8004e-05
# Epoch 170550, Train Loss: 2.0764e-05, test Loss: 1.7947e-05
# Epoch 170600, Train Loss: 2.0764e-05, test Loss: 1.7942e-05
# Epoch 170650, Train Loss: 2.0764e-05, test Loss: 1.7943e-05
# Epoch 170700, Train Loss: 2.0764e-05, test Loss: 1.7942e-05
# Epoch 170750, Train Loss: 2.0774e-05, test Loss: 1.7999e-05
# Epoch 170800, Train Loss: 2.0765e-05, test Loss: 1.7955e-05
# Epoch 170850, Train Loss: 2.0764e-05, test Loss: 1.7942e-05
# Epoch 170900, Train Loss: 2.0764e-05, test Loss: 1.7943e-05
# Epoch 170950, Train Loss: 2.0764e-05, test Loss: 1.7933e-05
# Epoch 171000, Train Loss: 2.0771e-05, test Loss: 1.8014e-05
# Epoch 171050, Train Loss: 2.0764e-05, test Loss: 1.7938e-05
# Epoch 171100, Train Loss: 2.0764e-05, test Loss: 1.7943e-05
# Epoch 171150, Train Loss: 2.0764e-05, test Loss: 1.7944e-05
# Epoch 171200, Train Loss: 2.0784e-05, test Loss: 1.7918e-05
# Epoch 171250, Train Loss: 2.0764e-05, test Loss: 1.7934e-05
# Epoch 171300, Train Loss: 2.0763e-05, test Loss: 1.7942e-05
# Epoch 171350, Train Loss: 2.0763e-05, test Loss: 1.7942e-05
# Epoch 171400, Train Loss: 2.0773e-05, test Loss: 1.8002e-05
# Epoch 171450, Train Loss: 2.0772e-05, test Loss: 1.7956e-05
# Epoch 171500, Train Loss: 2.0763e-05, test Loss: 1.7946e-05
# Epoch 171550, Train Loss: 2.0763e-05, test Loss: 1.7942e-05
# Epoch 171600, Train Loss: 2.0763e-05, test Loss: 1.7942e-05
# Epoch 171650, Train Loss: 2.1158e-05, test Loss: 1.8843e-05
# Epoch 171700, Train Loss: 2.0767e-05, test Loss: 1.7948e-05
# Epoch 171750, Train Loss: 2.0763e-05, test Loss: 1.7940e-05
# Epoch 171800, Train Loss: 2.0763e-05, test Loss: 1.7942e-05
# Epoch 171850, Train Loss: 2.0763e-05, test Loss: 1.7942e-05
# Epoch 171900, Train Loss: 2.0763e-05, test Loss: 1.7948e-05
# Epoch 171950, Train Loss: 2.0783e-05, test Loss: 1.7908e-05
# Epoch 172000, Train Loss: 2.0763e-05, test Loss: 1.7936e-05
# Epoch 172050, Train Loss: 2.0763e-05, test Loss: 1.7941e-05
# Epoch 172100, Train Loss: 2.0763e-05, test Loss: 1.7942e-05
# Epoch 172150, Train Loss: 2.0764e-05, test Loss: 1.7928e-05
# Epoch 172200, Train Loss: 2.0792e-05, test Loss: 1.7911e-05
# Epoch 172250, Train Loss: 2.0763e-05, test Loss: 1.7946e-05
# Epoch 172300, Train Loss: 2.0763e-05, test Loss: 1.7941e-05
# Epoch 172350, Train Loss: 2.0763e-05, test Loss: 1.7941e-05
# Epoch 172400, Train Loss: 2.0763e-05, test Loss: 1.7941e-05
# Epoch 172450, Train Loss: 2.0769e-05, test Loss: 1.8024e-05
# Epoch 172500, Train Loss: 2.0763e-05, test Loss: 1.7945e-05
# Epoch 172550, Train Loss: 2.0763e-05, test Loss: 1.7942e-05
# Epoch 172600, Train Loss: 2.0763e-05, test Loss: 1.7941e-05
# Epoch 172650, Train Loss: 2.0762e-05, test Loss: 1.7941e-05
# Epoch 172700, Train Loss: 2.2097e-05, test Loss: 1.9045e-05
# Epoch 172750, Train Loss: 2.0765e-05, test Loss: 1.7917e-05
# Epoch 172800, Train Loss: 2.0762e-05, test Loss: 1.7942e-05
# Epoch 172850, Train Loss: 2.0762e-05, test Loss: 1.7941e-05
# Epoch 172900, Train Loss: 2.0762e-05, test Loss: 1.7941e-05
# Epoch 172950, Train Loss: 2.0762e-05, test Loss: 1.7941e-05
# Epoch 173000, Train Loss: 2.0762e-05, test Loss: 1.7944e-05
# Epoch 173050, Train Loss: 2.0764e-05, test Loss: 1.7989e-05
# Epoch 173100, Train Loss: 2.0762e-05, test Loss: 1.7936e-05
# Epoch 173150, Train Loss: 2.0762e-05, test Loss: 1.7940e-05
# Epoch 173200, Train Loss: 2.0762e-05, test Loss: 1.7941e-05
# Epoch 173250, Train Loss: 2.0762e-05, test Loss: 1.7941e-05
# Epoch 173300, Train Loss: 2.0762e-05, test Loss: 1.7935e-05
# Epoch 173350, Train Loss: 2.0780e-05, test Loss: 1.7949e-05
# Epoch 173400, Train Loss: 2.0762e-05, test Loss: 1.7936e-05
# Epoch 173450, Train Loss: 2.0762e-05, test Loss: 1.7940e-05
# Epoch 173500, Train Loss: 2.0762e-05, test Loss: 1.7940e-05
# Epoch 173550, Train Loss: 2.0762e-05, test Loss: 1.7940e-05
# Epoch 173600, Train Loss: 2.0773e-05, test Loss: 1.7953e-05
# Epoch 173650, Train Loss: 2.0764e-05, test Loss: 1.7958e-05
# Epoch 173700, Train Loss: 2.0762e-05, test Loss: 1.7941e-05
# Epoch 173750, Train Loss: 2.0762e-05, test Loss: 1.7940e-05
# Epoch 173800, Train Loss: 2.0762e-05, test Loss: 1.7940e-05
# Epoch 173850, Train Loss: 2.0764e-05, test Loss: 1.7920e-05
# Epoch 173900, Train Loss: 2.0784e-05, test Loss: 1.7910e-05
# Epoch 173950, Train Loss: 2.0762e-05, test Loss: 1.7937e-05
# Epoch 174000, Train Loss: 2.0762e-05, test Loss: 1.7940e-05
# Epoch 174050, Train Loss: 2.0761e-05, test Loss: 1.7940e-05
# Epoch 174100, Train Loss: 2.0802e-05, test Loss: 1.8099e-05
# Epoch 174150, Train Loss: 2.0763e-05, test Loss: 1.7916e-05
# Epoch 174200, Train Loss: 2.0761e-05, test Loss: 1.7942e-05
# Epoch 174250, Train Loss: 2.0761e-05, test Loss: 1.7939e-05
# Epoch 174300, Train Loss: 2.0761e-05, test Loss: 1.7938e-05
# Epoch 174350, Train Loss: 2.0851e-05, test Loss: 1.7907e-05
# Epoch 174400, Train Loss: 2.0762e-05, test Loss: 1.7930e-05
# Epoch 174450, Train Loss: 2.0761e-05, test Loss: 1.7938e-05
# Epoch 174500, Train Loss: 2.0761e-05, test Loss: 1.7939e-05
# Epoch 174550, Train Loss: 2.1796e-05, test Loss: 1.8681e-05
# Epoch 174600, Train Loss: 2.0761e-05, test Loss: 1.7951e-05
# Epoch 174650, Train Loss: 2.0761e-05, test Loss: 1.7939e-05
# Epoch 174700, Train Loss: 2.0761e-05, test Loss: 1.7939e-05
# Epoch 174750, Train Loss: 2.0761e-05, test Loss: 1.7939e-05
# Epoch 174800, Train Loss: 2.1289e-05, test Loss: 1.8357e-05
# Epoch 174850, Train Loss: 2.0762e-05, test Loss: 1.7919e-05
# Epoch 174900, Train Loss: 2.0761e-05, test Loss: 1.7941e-05
# Epoch 174950, Train Loss: 2.0761e-05, test Loss: 1.7939e-05
# Epoch 175000, Train Loss: 2.0761e-05, test Loss: 1.7940e-05
# Epoch 175050, Train Loss: 2.0823e-05, test Loss: 1.7960e-05
# Epoch 175100, Train Loss: 2.0761e-05, test Loss: 1.7938e-05
# Epoch 175150, Train Loss: 2.0761e-05, test Loss: 1.7938e-05
# Epoch 175200, Train Loss: 2.0761e-05, test Loss: 1.7939e-05
# Epoch 175250, Train Loss: 2.0782e-05, test Loss: 1.7905e-05
# Epoch 175300, Train Loss: 2.0766e-05, test Loss: 1.7932e-05
# Epoch 175350, Train Loss: 2.0761e-05, test Loss: 1.7936e-05
# Epoch 175400, Train Loss: 2.0760e-05, test Loss: 1.7939e-05
# Epoch 175450, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 175500, Train Loss: 2.0928e-05, test Loss: 1.7908e-05
# Epoch 175550, Train Loss: 2.0760e-05, test Loss: 1.7946e-05
# Epoch 175600, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 175650, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 175700, Train Loss: 2.0761e-05, test Loss: 1.7946e-05
# Epoch 175750, Train Loss: 2.0767e-05, test Loss: 1.7932e-05
# Epoch 175800, Train Loss: 2.0760e-05, test Loss: 1.7944e-05
# Epoch 175850, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 175900, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 175950, Train Loss: 2.1260e-05, test Loss: 1.8531e-05
# Epoch 176000, Train Loss: 2.0763e-05, test Loss: 1.7922e-05
# Epoch 176050, Train Loss: 2.0760e-05, test Loss: 1.7937e-05
# Epoch 176100, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 176150, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 176200, Train Loss: 2.0913e-05, test Loss: 1.7957e-05
# Epoch 176250, Train Loss: 2.0760e-05, test Loss: 1.7934e-05
# Epoch 176300, Train Loss: 2.0760e-05, test Loss: 1.7937e-05
# Epoch 176350, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 176400, Train Loss: 2.0760e-05, test Loss: 1.7945e-05
# Epoch 176450, Train Loss: 2.0764e-05, test Loss: 1.7905e-05
# Epoch 176500, Train Loss: 2.0760e-05, test Loss: 1.7938e-05
# Epoch 176550, Train Loss: 2.0760e-05, test Loss: 1.7937e-05
# Epoch 176600, Train Loss: 2.0760e-05, test Loss: 1.7937e-05
# Epoch 176650, Train Loss: 2.0761e-05, test Loss: 1.7961e-05
# Epoch 176700, Train Loss: 2.0772e-05, test Loss: 1.7935e-05
# Epoch 176750, Train Loss: 2.0760e-05, test Loss: 1.7937e-05
# Epoch 176800, Train Loss: 2.0760e-05, test Loss: 1.7937e-05
# Epoch 176850, Train Loss: 2.0759e-05, test Loss: 1.7937e-05
# Epoch 176900, Train Loss: 2.0759e-05, test Loss: 1.7937e-05
# Epoch 176950, Train Loss: 2.0759e-05, test Loss: 1.7937e-05
# Epoch 177000, Train Loss: 2.0929e-05, test Loss: 1.8479e-05
# Epoch 177050, Train Loss: 2.0759e-05, test Loss: 1.7942e-05
# Epoch 177100, Train Loss: 2.0759e-05, test Loss: 1.7938e-05
# Epoch 177150, Train Loss: 2.0759e-05, test Loss: 1.7936e-05
# Epoch 177200, Train Loss: 2.0759e-05, test Loss: 1.7937e-05
# Epoch 177250, Train Loss: 2.0759e-05, test Loss: 1.7934e-05
# Epoch 177300, Train Loss: 2.0818e-05, test Loss: 1.7907e-05
# Epoch 177350, Train Loss: 2.0760e-05, test Loss: 1.7931e-05
# Epoch 177400, Train Loss: 2.0759e-05, test Loss: 1.7937e-05
# Epoch 177450, Train Loss: 2.0759e-05, test Loss: 1.7937e-05
# Epoch 177500, Train Loss: 2.0761e-05, test Loss: 1.7919e-05
# Epoch 177550, Train Loss: 2.0767e-05, test Loss: 1.7905e-05
# Epoch 177600, Train Loss: 2.0759e-05, test Loss: 1.7933e-05
# Epoch 177650, Train Loss: 2.0759e-05, test Loss: 1.7936e-05
# Epoch 177700, Train Loss: 2.0759e-05, test Loss: 1.7936e-05
# Epoch 177750, Train Loss: 2.1597e-05, test Loss: 1.8410e-05
# Epoch 177800, Train Loss: 2.0759e-05, test Loss: 1.7928e-05
# Epoch 177850, Train Loss: 2.0759e-05, test Loss: 1.7934e-05
# Epoch 177900, Train Loss: 2.0759e-05, test Loss: 1.7936e-05
# Epoch 177950, Train Loss: 2.0788e-05, test Loss: 1.7903e-05
# Epoch 178000, Train Loss: 2.0761e-05, test Loss: 1.7937e-05
# Epoch 178050, Train Loss: 2.0759e-05, test Loss: 1.7934e-05
# Epoch 178100, Train Loss: 2.0759e-05, test Loss: 1.7936e-05
# Epoch 178150, Train Loss: 2.0759e-05, test Loss: 1.7936e-05
# Epoch 178200, Train Loss: 2.0935e-05, test Loss: 1.7903e-05
# Epoch 178250, Train Loss: 2.0760e-05, test Loss: 1.7946e-05
# Epoch 178300, Train Loss: 2.0758e-05, test Loss: 1.7936e-05
# Epoch 178350, Train Loss: 2.0758e-05, test Loss: 1.7936e-05
# Epoch 178400, Train Loss: 2.0758e-05, test Loss: 1.7936e-05
# Epoch 178450, Train Loss: 2.1327e-05, test Loss: 1.9159e-05
# Epoch 178500, Train Loss: 2.0768e-05, test Loss: 1.7912e-05
# Early stopping at epoch 178518, best test loss: 1.7901e-05
# 训练完成，最终验证损失： tensor(1.7901e-05, device='cuda:0')

# %% [markdown]
# ## 训练结果

# %% [markdown]
# ### 打印参数结果

# %%
print(params)
# Out:
# {'r1': Parameter containing:
# tensor([7.0749e-05], device='cuda:0', requires_grad=True), 'r2': Parameter containing:
# tensor([1.5519e-06], device='cuda:0', requires_grad=True), 's1': Parameter containing:
# tensor([0.0631], device='cuda:0', requires_grad=True), 't1': Parameter containing:
# tensor([-0.1193], device='cuda:0', requires_grad=True), 't2': Parameter containing:
# tensor([11.8858], device='cuda:0', requires_grad=True), 't3': Parameter containing:
# tensor([-53.2803], device='cuda:0', requires_grad=True), 'c1': Parameter containing:
# tensor([-0.0267], device='cuda:0', requires_grad=True), 'c2': Parameter containing:
# tensor([0.4285], device='cuda:0', requires_grad=True)}

# %% [markdown]
# ### 保存结果参数

# %%
torch.save(params, r'D:\Devs\Single_Stack_MLJ\src\Model\Static_Model\Static_Electrochemical_params_Hyzenis.pth')

# %% [markdown]
# ### 预测真实对比图

# %%
params = torch.load(r'D:\Devs\Single_Stack_MLJ\src\Model\Static_Model\Static_Electrochemical_params_Hyzenis.pth')

# %%
V_pred = cell_voltage_cal_empirical_formula(statistics=statistics_torch,
                                            **params)
V_pred_np = V_pred.cpu().detach().numpy()
cell_voltage_observed_np = cell_voltage_observed_torch.cpu().detach().numpy()

fig, ax1 = plt.subplots(figsize=(18,5))

ax1.scatter(range(len(V_pred_np)), V_pred_np, alpha = 0.7, c = 'r', label = '预测值')
ax1.scatter(range(len(V_pred_np)), cell_voltage_observed_np, label = '真实值')
ax1.legend()

plt.title('稳态电模型耦合结果', fontsize = 15)
plt.xlabel('数据点')
plt.ylabel('小室电压')
plt.grid()

# %% [markdown]
# # 画极化曲线

# %%
t1=params['t1'].item()
t2=params['t2'].item()
t3=params['t3'].item()
r1=params['r1'].item()
r2=params['r2'].item()
s1=params['s1'].item()

c1=params['c1'].item()
c2=params['c2'].item()

# %%
print(params)

# %%
  # 稳态电化学模型
def Static_Electrochemical_Model(Lye_temp, Temp_out, Current_density, Lye_flow, Pressure = 1.6):
    """电解电压的计算模型

    Args:
        Lye_temp (float): 进口温度，即碱液温度 ℃
        Temp_out (float): 出口温度℃
        Current_density (float): 电流密度 A/m2
        Lye_flow (float): 碱液流量 m3/h
        Pressure (float): 压力 MPa

    Returns:
        float: 电解小室电压 V
    """

    # 避免 T_in 或 T_out 为零
    Lye_temp = max(Lye_temp, 1e-10)
    Temp_out = max(Temp_out, 1e-10)

    lambda_flow = Lye_flow / Volume_active / 25 + 0.1

    temp_work = (1-lambda_flow) * Lye_temp * c1 + lambda_flow * Temp_out * c2

    # 避免 log 函数的负数输入
    log_input = max((t1 + t2 / temp_work + t3 / temp_work ** 2) * Current_density + 1, 1e-10)

    Vcell= 1.25 + (r1 + r2 * temp_work) * Current_density + s1 * math.log(log_input)

    return Vcell

# %%
df_choose_point = df_date_Hyzenis.copy()
df_choose_point = df_choose_point[[Cols.current_density, Cols.cell_voltage, Cols.temp_out, Cols.lye_temp]]
df_choose_point_result = df_choose_point[(df_choose_point[Cols.temp_out] >= 84.9) & (df_choose_point[Cols.temp_out] <= 85.1) & (df_choose_point[Cols.lye_temp] >= 65.9) & (df_choose_point[Cols.lye_temp] <= 66.1)]

print(df_choose_point_result)

# %%
# 定义电流密度范围
current_densities = np.linspace(0, 4000, 400)

# 定义温度组合
temperature_combinations = [(58, 70), (62, 80), (68, 85)]

# 碱液流量和压力
Lye_flow = 0.4
Pressure = 1.6

# 初始化绘图
plt.figure(figsize=(18, 10))

# 遍历不同的温度组合
for Lye_temp, Temp_out in temperature_combinations:
    # 计算每个电流密度下的电池电压
    voltages = []
    for Current_density in current_densities:
        Vcell = Static_Electrochemical_Model(Lye_temp, Temp_out, Current_density, Lye_flow)
        voltages.append(Vcell)

    # 绘制极化曲线
    plt.plot(current_densities, voltages, label=f'Lye_temp={Lye_temp}°C, Temp_out={Temp_out}°C')

plt.plot(df_choose_point_result[Cols.current_density], df_choose_point_result[Cols.cell_voltage])

# 设置图表标题和标签
# plt.title('Polarization Curves at Different Temperature Combinations')
plt.xlabel('Current Density (A/m²)', fontsize=28)
plt.ylabel('Cell Voltage (V)', fontsize=28)
plt.legend(loc='lower right', fontsize=28)
plt.grid(True)

# 显示图表
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(V_pred_np, cell_voltage_observed_np)
print(r2)

# %%
plt.figure(figsize=(12,8))
plt.scatter(cell_voltage_observed_np, V_pred_np)
# plt.title('稳态电模型预测结果')
plt.xlabel('Ture voltage (V)', fontsize=28)
plt.ylabel('Predicted voltage (V)', fontsize=28)
# 获取当前的 Axes 对象
ax = plt.gca()
# 获取坐标轴的范围
x_min, x_max = ax.get_xlim()
y_min, y_max = ax.get_ylim()
# 确定对角线的端点
diag_min = min(x_min, y_min)
diag_max = max(x_max, y_max)
plt.grid(True)
# 绘制对角线
plt.plot([diag_min, diag_max], [diag_min, diag_max], color='red', linestyle='--')

# 绘制空白框并添加文本
plt.text(
    x=1.862, y=1.832,  # 文本框中心坐标（相对画布比例，0-1范围）
    s="R$^2$=0.967\nMSE=2.667E-6",  # 文本内容
    fontsize=20,    # 字体大小
    ha='center',    # 水平居中
    va='center',    # 垂直居中
    bbox=dict(      # 空白框样式设置
        facecolor='white',  # 框内填充色（白色=空白）
        edgecolor='black',  # 边框颜色
        boxstyle='square,pad=0.6'  # 框样式（round=圆角，pad=内边距）
    )
)

# %%
lye_flow_array = np.arange(0.3, 0.5, 0.005)
lye_temp_array = np.linspace(55, 75, len(lye_flow_array))
voltage_array = np.array([])

for i in range(len(lye_flow_array)):

    voltage = Static_Electrochemical_Model(Lye_temp = lye_temp_array[i],
                                                       Temp_out = 85,
                                                       Current_density = 3500,
                                                       Lye_flow = lye_flow_array[i],
                                                       Pressure=1.6)
    voltage_array = np.append(voltage_array, voltage)

plt.plot(voltage_array)
